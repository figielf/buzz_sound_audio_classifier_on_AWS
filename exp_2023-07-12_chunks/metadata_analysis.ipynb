# %%
import pandas as pd

# %%
metadata = pd.read_csv('metadata.csv')

# %%
metadata.head()
# Out:
#                                            file_name  \
# 0  Roeselianaroeselii_XC751814-dat028-019_edit1_c...
# 1  Roeselianaroeselii_XC751814-dat028-019_edit1_c...
# 2  Roeselianaroeselii_XC751814-dat028-019_edit1_c...
# 3  Roeselianaroeselii_XC751814-dat028-019_edit1_c...
# 4  Roeselianaroeselii_XC751814-dat028-019_edit1_c...
#
#                               unique_file  \
# 0  Roeselianaroeselii_XC751814-dat028-019
# 1  Roeselianaroeselii_XC751814-dat028-019
# 2  Roeselianaroeselii_XC751814-dat028-019
# 3  Roeselianaroeselii_XC751814-dat028-019
# 4  Roeselianaroeselii_XC751814-dat028-019
#
#                                                 path             species  \
# 0  data/data_chunks/train/Roeselianaroeselii_XC75...  Roeselianaroeselii
# 1  data/data_chunks/train/Roeselianaroeselii_XC75...  Roeselianaroeselii
# 2  data/data_chunks/train/Roeselianaroeselii_XC75...  Roeselianaroeselii
# 3  data/data_chunks/train/Roeselianaroeselii_XC75...  Roeselianaroeselii
# ...

# %%
metadata[metadata['length'] < 2]
# Out:
#                                               file_name  \
# 16    Atrapsaltacorticina_GBIF2901504947_IN62966536_...
# 28    Omocestusviridulus_XC752267-dat013-003_edit2_c...
# 71    Conocephalusfuscus_XC752389-dat033-002_edit6_c...
# 98    Phaneropterafalcata_XC751637-dat030-014_edit1_...
# 141   Stenobothruslineatus_XC752396-dat025-007_edit3...
# ...                                                 ...
# 8492  Decticusverrucivorus_XC751907-dat098-009_cut6.wav
# 8516  Grylluscampestris_XC751422-dat010-001_edit3_cu...
# 8535  Omocestusviridulus_XC752264-dat012-008_edit8_c...
# 8546  Chorthippusbrunneus_XC751387-dat005-058_edit4_...
# 8582             Nemobiussylvestris_VOC_120808-0078.wav
#
#                                             unique_file  \
# 16    Atrapsaltacorticina_GBIF2901504947_IN62966536_...
# 28               Omocestusviridulus_XC752267-dat013-003
# 71               Conocephalusfuscus_XC752389-dat033-002
# 98              Phaneropterafalcata_XC751637-dat030-014
# ...

# %%
'_cut' in metadata[metadata['length'] < 0.5]['file_name'].iloc[[0]].values[0]
# Out:
# True

# %%
['_cut' in metadata[metadata['length'] <= 1]['file_name'].iloc[[i]].values[0] for i in range(len(metadata[metadata['length'] <= 1]))]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
# ...
