# %% [markdown]
# # Tutorial 5 - Getting better results with SageMaker training jobs

# %% [markdown]
# In the last tutorial, we trained and evaluated the first model on a small sample of data. While it is possible to train a model within [Sagemaker Studio](https://www.youtube.com/watch?v=uQc8Itd4UTs&list=PLhr1KZpdzukcOr_6j_zmSrvYnLUtgqsZz) it's better to use a Sagemaker training job instead. Sagemaker training jobs have several advantages over a normal notebook. To name few of them:
#
# - provide you with a nice overview of all the training you ran
# - automatically store the results of a training run (metrics, [logs](https://console.aws.amazon.com/cloudwatch) and models)
# - do not automatically shut down after a few hours (which we enabled in the notebooks)
# - allows running multiple training jobs in parallel (if you have sufficient GPUs allocated)
#
# In this notebook, we will convert the approach from tutorial 4 into a Sagemaker training job and train our model on the full data set. During the training, the logs are sent to [Cloudwatch](https://console.aws.amazon.com/cloudwatch) - AWS monitoring service. After the training is completed, the model is saved and automatically uploaded to S3. From there we'll retrieve the model and evaluate it.
#
# **NOTE: We will NOT need a GPU for this tutorial notebook. Pick a non-GPU instance type to save costs.**

# %% [markdown]
# import os
# import shutil
# import datetime
# import zipfile## Setup
#
# First, we need to import required libraries and functions.

# %%
#df[['label']].value_counts()

# %%
import sys                                                                             # Python system library needed to load custom functions
import numpy as np                                                                     # for performing calculations on numerical arrays
import pandas as pd                                                                    # home of the DataFrame construct, _the_ most important object for Data Science
import seaborn as sns                                                                  # additional plotting library
import matplotlib.pyplot as plt                                                        # allows creation of insightful plots
import os                                                                              # for changing the directory

import sagemaker                                                                       # dedicated sagemaker library to execute training jobs
import boto3                                                                           # for interacting with S3 buckets

from sagemaker.huggingface import HuggingFace                                           # for executing the trainig jobs
from sklearn.metrics import precision_recall_fscore_support, accuracy_score             # tools to understand how our model is performing

from data_utils import copy_data_to_s3, TARGET_FOLDER
from results_utils import archive_solution_files
CURRENT_SCRIPT_FULL_PATH = os.getcwd()
CURRENT_SCRIPT_DIRECTORY = os.path.basename(CURRENT_SCRIPT_FULL_PATH)

#sys.path.append('')                                                               # Add the source directory to the PYTHONPATH. This allows to import local functions and modules.
from config import DEFAULT_BUCKET, DEFAULT_REGION  
from gdsc_utils import create_encrypted_bucket, download_and_extract_model, PROJECT_DIR # functions to create S3 buckets and to help with downloading models. Importing our root directory
from gdsc_eval import plot_confusion_matrix                                             # function for creating confusion matrix                                     # importing the bucket name that contains data for the challenge and the default region
os.chdir(PROJECT_DIR)                                                                   # changing our directory to root

# %% [markdown]
# # Running the Training Script
#
# The training job will run on a virtual machine (called an instance) in the AWS cloud. An overview of all your training jobs can be found in the [AWS console](https://us-east-1.console.aws.amazon.com/sagemaker/home?region=us-east-1#/jobs) (you may have to change the region) after you logged into your account. You can also navigate directly to *Amazon SageMaker > Training > Training jobs* and click on the name of the latest training job.
#
# To start, we need to set the name of our experiment. Keep in mind that every experiment should have a unique name. Since we advise you to use a separate Python script for each training, we'll use the name of the training script as the name of the experiment.

# %%
entry_point = 'baseline_ast_train.py'
exp_name = entry_point.split('.')[0].replace('_', '-')  # AWS does not allow . and _ as experiment names
exp_name
# Out:
# 'baseline-ast-train'

# %% [markdown]
# Next, we need to define the AWS settings for the job.

# %%
account_id = boto3.client('sts').get_caller_identity().get('Account')
role = sagemaker.get_execution_role()

# %% [markdown]
# We will also need to download the data to train a model. Luckily, Sagemaker has built-in functionality for this.
# Via the ```input_channels``` parameter we can specify multiple S3 locations. The contents are downloaded in the training job and made available under the provided name (dictionary key).
# In the example below, Sagemaker will download the complete content of the training data bucket, store it on the instance and, save its location in an environment variable called ```SM_CHANNEL_DATA```.<br>
# You can define up to 20 different channels.

# %% [markdown]
# Below is the required structure in our **S3_bucket** that needs to be followed to create the HuggingFace dataset without any issues. The *metadata.csv* file should contain two columns:
# - file_name - the name of the file,
# - label - the ground truth label for that file.
#
# As we do not have labels for the test set, we only include the *file_name* column in the *metadata.csv* in the test directory.
#
# ```
# S3_bucket/
#     └── data/
#         |── labels.json
#         └── train/
#             |── train_file_1.wav
#             |── train_file_2.wav
#             |── ...
#             |── metadata.csv
#         └── val/
#             |── val_file_1.wav
#             |── val_file_2.wav
#             |── ...
#             |── metadata.csv
#         └── test/
#             |── test_file_1.wav
#             |── test_file_2.wav
#             |── ...
#             |── metadata.csv
# ```

# %%
from gdsc_utils import download_directory

download_directory(s3_path='data_copied_by_data_utils_py/data_5_classes', local_dir='/experiments/data_test', bucket='sagemaker-us-east-1-292159885427', region=DEFAULT_REGION)
# Out:
# 720it [00:00, 2832.93it/s]

# %%
# prepare data
# copying test data take long tine, so test data will not be copied, theys will be taken directly from oryginal bucket, please check 'test_oryginal_path' kiperparameter below
#map_filter = {class_id:i for i, class_id in enumerate([7, 10, 19, 23, 27, 28, 29, 50, 51, 52])}
map_filter = {class_id:i for i, class_id in enumerate([7, 10, 23, 27, 50])}

s3_bucket_data_subfolder = 'data_5_classes'

copy_data_to_s3(source_folder='', 
                subfolders=['train', 'val', 'test'],
                data_map_filter=map_filter, 
                s3_client=boto3.client("s3"),
                bucket_name=f'sagemaker-{DEFAULT_REGION}-{account_id}',
                bucket_subfolder=s3_bucket_data_subfolder)
# Out:
# Loaded base labels from /root/data/data/labels.json and start filtering
# labels filtered:
#  {'Chorthippusalbomarginatus': 0, 'Chorthippusbrunneus': 1, 'Eupholidopteraschmidti': 2, 'Gomphocerussibiricus': 3, 'Platypleurasp13': 4}
# Saved labels in /root/data/data/data_copied_by_data_utils_py/labels.json
# Copied '/root/data/data/data_copied_by_data_utils_py/labels.json' to 'data_copied_by_data_utils_py/data_5_classes/labels.json' in S3 bucket 'sagemaker-us-east-1-292159885427'.
#
# Start copying train data to s3
# Loaded base metadata from /root/data/data/train/metadata.csv and start filtering
# Index(['file_name', 'label'], dtype='object')
# Saved metadata in /root/data/data/data_copied_by_data_utils_py/train/metadata.csv
# Copied '/root/data/data/data_copied_by_data_utils_py/train/metadata.csv' to 'data_copied_by_data_utils_py/data_5_classes/train/metadata.csv' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC752430-dat051-014_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC752430-dat051-014_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751407-dat024-016_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751407-dat024-016_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751880-dat055-005_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751880-dat055-005_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751388-dat007-005_edit6.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751388-dat007-005_edit6.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751388-dat007-005_edit7.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751388-dat007-005_edit7.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751544-dat011-005_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751544-dat011-005_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%235_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%235_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751325-dat055-004_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751325-dat055-004_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusalbomarginatus_XC751373-dat001-024_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusalbomarginatus_XC751373-dat001-024_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751407-dat024-016_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751407-dat024-016_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC752430-dat051-014_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC752430-dat051-014_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751399-dat022-009_edit5.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751399-dat022-009_edit5.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751880-dat055-005_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751880-dat055-005_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751544-dat011-005_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751544-dat011-005_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751388-dat007-005_edit5.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751388-dat007-005_edit5.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751388-dat007-005_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751388-dat007-005_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Platypleurasp13_MHV%201486%20P.sp%2013%20nr%20Gamtoos%20River%20Bridge%20%233_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Platypleurasp13_MHV%201486%20P.sp%2013%20nr%20Gamtoos%20River%20Bridge%20%233_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751544-dat011-005_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751544-dat011-005_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751325-dat055-004_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751325-dat055-004_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751399-dat022-009_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751399-dat022-009_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751407-dat024-016_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751407-dat024-016_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC752430-dat051-014_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC752430-dat051-014_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751315-dat049-005_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751315-dat049-005_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC752433-dat051-017_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC752433-dat051-017_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751386-dat005-057.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751386-dat005-057.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC752431-dat051-015.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC752431-dat051-015.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751388-dat007-005_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751388-dat007-005_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751885-dat056-011_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751885-dat056-011_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751399-dat022-009_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751399-dat022-009_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751315-dat049-005_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751315-dat049-005_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751399-dat022-009_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751399-dat022-009_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC752433-dat051-017_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC752433-dat051-017_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751544-dat011-005_edit5.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751544-dat011-005_edit5.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751388-dat007-005_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751388-dat007-005_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751388-dat007-005_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751388-dat007-005_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751544-dat011-005_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751544-dat011-005_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751885-dat056-011_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751885-dat056-011_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751315-dat049-005_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751315-dat049-005_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751399-dat022-009_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751399-dat022-009_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751317-dat049-006_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751317-dat049-006_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusalbomarginatus_XC751405-dat024-001.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusalbomarginatus_XC751405-dat024-001.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751382-dat005-046.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751382-dat005-046.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751317-dat049-006_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751317-dat049-006_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751520-dat003-020 19.10.01_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751520-dat003-020 19.10.01_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751886-dat056-015_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751886-dat056-015_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusalbomarginatus_XC751378-dat001-032.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusalbomarginatus_XC751378-dat001-032.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751883-dat056-009.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751883-dat056-009.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Platypleurasp13_MHV%201486%20P.sp%2013%20nr%20Gamtoos%20River%20Bridge%20%232_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Platypleurasp13_MHV%201486%20P.sp%2013%20nr%20Gamtoos%20River%20Bridge%20%232_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751317-dat049-006_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751317-dat049-006_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751520-dat003-020 19.10.01_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751520-dat003-020 19.10.01_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%232_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%232_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC752229-dat113-016_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC752229-dat113-016_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751886-dat056-015_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751886-dat056-015_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Platypleurasp13_MHV%201490%20P.sp%2013%20Gamtoos%20Pass%20%231_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Platypleurasp13_MHV%201490%20P.sp%2013%20Gamtoos%20Pass%20%231_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751520-dat003-020_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751520-dat003-020_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751794-dat187-003_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751794-dat187-003_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusalbomarginatus_XC751376-dat001-030.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusalbomarginatus_XC751376-dat001-030.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC752229-dat113-016_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC752229-dat113-016_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751520-dat003-020 19.10.01_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751520-dat003-020 19.10.01_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC752229-dat113-016_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC752229-dat113-016_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%232_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%232_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751886-dat056-015_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751886-dat056-015_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Platypleurasp13_MHV%201490%20P.sp%2013%20Gamtoos%20Pass%20%231_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Platypleurasp13_MHV%201490%20P.sp%2013%20Gamtoos%20Pass%20%231_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751520-dat003-020_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751520-dat003-020_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751520-dat003-020_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751520-dat003-020_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751794-dat187-003_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751794-dat187-003_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751886-dat056-015_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751886-dat056-015_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC752156-dat124-004.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC752156-dat124-004.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751520-dat003-020 19.10.01_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751520-dat003-020 19.10.01_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751318-dat051-001_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751318-dat051-001_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751406-dat024-015_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751406-dat024-015_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751380-dat005-044_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751380-dat005-044_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751381-dat005-045_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751381-dat005-045_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751391-dat054-007_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751391-dat054-007_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751318-dat051-001_edit5.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751318-dat051-001_edit5.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751318-dat051-001_edit7.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751318-dat051-001_edit7.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Platypleurasp13_MHV%201486%20P.sp%2013%20nr%20Gamtoos%20River%20Bridge%20%231_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Platypleurasp13_MHV%201486%20P.sp%2013%20nr%20Gamtoos%20River%20Bridge%20%231_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751406-dat024-015_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751406-dat024-015_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751881-dat055-006.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751881-dat055-006.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751380-dat005-044_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751380-dat005-044_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751406-dat024-015_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751406-dat024-015_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751391-dat054-007_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751391-dat054-007_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751383-dat005-048.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751383-dat005-048.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751318-dat051-001_edit6.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751318-dat051-001_edit6.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751318-dat051-001_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751318-dat051-001_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751379-dat005-042_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751379-dat005-042_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751406-dat024-015_edit7.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751406-dat024-015_edit7.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751831-dat001-040_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751831-dat001-040_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Platypleurasp13_MHV%201490%20P.sp%2013%20Gamtoos%20Pass%20%232_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Platypleurasp13_MHV%201490%20P.sp%2013%20Gamtoos%20Pass%20%232_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751406-dat024-015_edit6.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751406-dat024-015_edit6.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751318-dat051-001_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751318-dat051-001_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%231_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%231_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC751318-dat051-001_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC751318-dat051-001_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751379-dat005-042_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751379-dat005-042_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751406-dat024-015_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751406-dat024-015_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751831-dat001-040_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751831-dat001-040_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusalbomarginatus_XC751400-dat023-001.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusalbomarginatus_XC751400-dat023-001.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751371-dat001-022.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751371-dat001-022.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751406-dat024-015_edit5.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751406-dat024-015_edit5.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751379-dat005-042_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751379-dat005-042_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%231_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%231_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751387-dat005-058_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751387-dat005-058_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751387-dat005-058_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751387-dat005-058_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_Take92.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_Take92.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751387-dat005-058_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751387-dat005-058_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751796-dat187-005_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751796-dat187-005_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusalbomarginatus_XC751375-dat001-029.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusalbomarginatus_XC751375-dat001-029.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_CHOBRU_20180914_141921.M.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_CHOBRU_20180914_141921.M.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Eupholidopteraschmidti_XC752427-dat056-002.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Eupholidopteraschmidti_XC752427-dat056-002.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusalbomarginatus_XC751374-dat001-028.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusalbomarginatus_XC751374-dat001-028.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751796-dat187-005_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751796-dat187-005_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751796-dat187-005_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751796-dat187-005_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Chorthippusbrunneus_XC751387-dat005-058_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Chorthippusbrunneus_XC751387-dat005-058_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/train/Gomphocerussibiricus_XC751796-dat187-005_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/train/Gomphocerussibiricus_XC751796-dat187-005_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Saved 114 entries in metadata
# Copied 114 wav files from /root/data/data/train to /root/data/data/data_copied_by_data_utils_py/train
# Copy finished
#
#
# Start copying val data to s3
# Loaded base metadata from /root/data/data/val/metadata.csv and start filtering
# Index(['file_name', 'label'], dtype='object')
# Saved metadata in /root/data/data/data_copied_by_data_utils_py/val/metadata.csv
# Copied '/root/data/data/data_copied_by_data_utils_py/val/metadata.csv' to 'data_copied_by_data_utils_py/data_5_classes/val/metadata.csv' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751398-dat022-008_edit5.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751398-dat022-008_edit5.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Eupholidopteraschmidti_XC752428-dat056-006_edit5.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Eupholidopteraschmidti_XC752428-dat056-006_edit5.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Eupholidopteraschmidti_XC752428-dat056-006_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Eupholidopteraschmidti_XC752428-dat056-006_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Eupholidopteraschmidti_XC752434-dat051-018_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Eupholidopteraschmidti_XC752434-dat051-018_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751398-dat022-008_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751398-dat022-008_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751398-dat022-008_edit6.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751398-dat022-008_edit6.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Eupholidopteraschmidti_XC752434-dat051-018_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Eupholidopteraschmidti_XC752434-dat051-018_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Eupholidopteraschmidti_XC752434-dat051-018_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Eupholidopteraschmidti_XC752434-dat051-018_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751398-dat022-008_edit7.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751398-dat022-008_edit7.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751398-dat022-008_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751398-dat022-008_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Eupholidopteraschmidti_XC752428-dat056-006_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Eupholidopteraschmidti_XC752428-dat056-006_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Eupholidopteraschmidti_XC752428-dat056-006_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Eupholidopteraschmidti_XC752428-dat056-006_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Gomphocerussibiricus_XC751884-dat056-010_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Gomphocerussibiricus_XC751884-dat056-010_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_GBIF3384023749_IN95761463_308346_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_GBIF3384023749_IN95761463_308346_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751398-dat022-008_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751398-dat022-008_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Gomphocerussibiricus_XC751884-dat056-010_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Gomphocerussibiricus_XC751884-dat056-010_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Eupholidopteraschmidti_XC752428-dat056-006_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Eupholidopteraschmidti_XC752428-dat056-006_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Gomphocerussibiricus_XC751884-dat056-010_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Gomphocerussibiricus_XC751884-dat056-010_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_GBIF3384023749_IN95761463_308346_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_GBIF3384023749_IN95761463_308346_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751398-dat022-008_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751398-dat022-008_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751370-dat001-021_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751370-dat001-021_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%234_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Platypleurasp13_MHV%201487%20P.sp%2013%20nr%20Thornhill%20%234_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751385-dat005-051.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751385-dat005-051.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751370-dat001-021_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751370-dat001-021_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusalbomarginatus_XC751377-dat001-031.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusalbomarginatus_XC751377-dat001-031.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751545-dat011-006_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751545-dat011-006_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Gomphocerussibiricus_XC751819-dat178-001_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Gomphocerussibiricus_XC751819-dat178-001_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Gomphocerussibiricus_XC751819-dat178-001_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Gomphocerussibiricus_XC751819-dat178-001_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusalbomarginatus_XC751394-dat022-011_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusalbomarginatus_XC751394-dat022-011_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751545-dat011-006_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751545-dat011-006_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751545-dat011-006_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751545-dat011-006_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusalbomarginatus_XC751394-dat022-011_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusalbomarginatus_XC751394-dat022-011_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Gomphocerussibiricus_XC751819-dat178-001_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Gomphocerussibiricus_XC751819-dat178-001_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusalbomarginatus_XC751394-dat022-011_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusalbomarginatus_XC751394-dat022-011_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751545-dat011-006_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751545-dat011-006_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusalbomarginatus_XC751394-dat022-011_edit5.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusalbomarginatus_XC751394-dat022-011_edit5.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusalbomarginatus_XC751394-dat022-011_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusalbomarginatus_XC751394-dat022-011_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751384-dat005-049_edit2.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751384-dat005-049_edit2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Gomphocerussibiricus_XC751600-dat097-003.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Gomphocerussibiricus_XC751600-dat097-003.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751384-dat005-049_edit3.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751384-dat005-049_edit3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751384-dat005-049_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751384-dat005-049_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Platypleurasp13_MHV%201016%20P.sp13%20nr%20Hankey_edit1.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Platypleurasp13_MHV%201016%20P.sp13%20nr%20Hankey_edit1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751384-dat005-049_edit4.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751384-dat005-049_edit4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751384-dat005-049_edit5.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751384-dat005-049_edit5.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751372-dat001-023.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751372-dat001-023.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/val/Chorthippusbrunneus_XC751384-dat005-049_edit6.wav' to 'data_copied_by_data_utils_py/data_5_classes/val/Chorthippusbrunneus_XC751384-dat005-049_edit6.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Saved 46 entries in metadata
# Copied 46 wav files from /root/data/data/val to /root/data/data/data_copied_by_data_utils_py/val
# Copy finished
#
#
# Start copying test data to s3
# Loaded base metadata from /root/data/data/test/metadata.csv and start filtering
# Index(['file_name'], dtype='object')
# Saved metadata in /root/data/data/data_copied_by_data_utils_py/test/metadata.csv
# Copied '/root/data/data/data_copied_by_data_utils_py/test/metadata.csv' to 'data_copied_by_data_utils_py/data_5_classes/test/metadata.csv' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/0.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/0.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/1.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/1.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/2.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/2.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/3.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/3.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/4.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/4.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/5.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/5.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/6.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/6.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/7.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/7.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/8.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/8.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/9.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/9.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/10.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/10.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/11.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/11.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/12.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/12.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/13.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/13.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/14.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/14.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/15.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/15.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/16.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/16.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/17.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/17.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/18.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/18.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/19.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/19.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/20.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/20.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/21.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/21.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/22.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/22.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/23.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/23.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/24.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/24.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/25.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/25.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/26.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/26.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/27.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/27.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/28.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/28.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/29.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/29.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/30.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/30.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/31.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/31.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/32.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/32.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/33.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/33.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/34.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/34.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/35.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/35.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/36.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/36.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/37.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/37.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/38.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/38.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/39.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/39.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/40.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/40.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/41.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/41.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/42.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/42.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/43.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/43.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/44.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/44.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/45.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/45.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/46.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/46.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/47.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/47.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/48.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/48.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/49.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/49.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/50.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/50.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/51.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/51.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# ...
# Copied '/root/data/data/test/450.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/450.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/451.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/451.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/452.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/452.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/453.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/453.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/454.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/454.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/455.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/455.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/456.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/456.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/457.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/457.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/458.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/458.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/459.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/459.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/460.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/460.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/461.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/461.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/462.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/462.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/463.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/463.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/464.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/464.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/465.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/465.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/466.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/466.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/467.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/467.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/468.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/468.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/469.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/469.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/470.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/470.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/471.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/471.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/472.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/472.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/473.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/473.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/474.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/474.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/475.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/475.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/476.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/476.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/477.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/477.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/478.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/478.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/479.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/479.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/480.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/480.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/481.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/481.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/482.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/482.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/483.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/483.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/484.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/484.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/485.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/485.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/486.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/486.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/487.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/487.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/488.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/488.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/489.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/489.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/490.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/490.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/491.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/491.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/492.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/492.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/493.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/493.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/494.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/494.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/495.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/495.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/496.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/496.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/497.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/497.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/498.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/498.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/499.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/499.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/500.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/500.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/501.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/501.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/502.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/502.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/503.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/503.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/504.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/504.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/505.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/505.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/506.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/506.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/507.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/507.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/508.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/508.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/509.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/509.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/510.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/510.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/511.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/511.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/512.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/512.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/513.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/513.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/514.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/514.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/515.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/515.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/516.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/516.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/517.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/517.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/518.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/518.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/519.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/519.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/520.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/520.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/521.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/521.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/522.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/522.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/523.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/523.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/524.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/524.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/525.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/525.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/526.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/526.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/527.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/527.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/528.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/528.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/529.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/529.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/530.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/530.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/531.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/531.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/532.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/532.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/533.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/533.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/534.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/534.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/535.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/535.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/536.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/536.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/537.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/537.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/538.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/538.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/539.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/539.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/540.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/540.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/541.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/541.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/542.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/542.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/543.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/543.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/544.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/544.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/545.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/545.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/546.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/546.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/547.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/547.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/548.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/548.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/549.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/549.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/550.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/550.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/551.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/551.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/552.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/552.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/553.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/553.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/554.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/554.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Copied '/root/data/data/test/555.wav' to 'data_copied_by_data_utils_py/data_5_classes/test/555.wav' in S3 bucket 'sagemaker-us-east-1-292159885427'.
# Saved 556 entries in metadata
# Copied 556 wav files from /root/data/data/test to /root/data/data/data_copied_by_data_utils_py/test
# Copy finished

# %%
input_channels = {    
    #"data": f"s3://{DEFAULT_BUCKET}/data"
    "data": f's3://sagemaker-{DEFAULT_REGION}-{account_id}/{TARGET_FOLDER}/{s3_bucket_data_subfolder}'
    
}
input_channels

# %% [markdown]
# We also specify where Sagemaker should store the results of the training job - i.e. the weights of the trained model. You will also see the link at the bottom of the training job overview page. If you already created a specific bucket for that purpose change ```s3_output_location``` variable to this bucket name

# %%
# We need to create our own s3 bucket if it doesn't exist yet:
sagemaker_bucket = f"sagemaker-{DEFAULT_REGION}-{account_id}"
create_encrypted_bucket(sagemaker_bucket)

s3_output_location = f"s3://{sagemaker_bucket}/{exp_name}"
s3_output_location
# Out:
# 's3://sagemaker-us-east-1-292159885427/baseline-ast-train'

# %%
# calculate mean and std of train spectograms
from transformers import ASTFeatureExtractor
from datasets import load_dataset

train_dataset = load_dataset("audiofolder", data_dir=train_path).get('train') # .shuffle(seed = 42)  # load the dataset and shuffle the examples
train_dataset = train_dataset.cast_column("audio", Audio(sampling_rate=MODEL_SAMPLING_RATE))
feature_extractor_stats = ASTFeatureExtractor.from_pretrained("MIT/ast-finetuned-audioset-10-10-0.4593", do_normalize=False)
train_dataset = train_dataset.map(lambda x: calculate_stats(x, audio_field='audio', array_field='array', feature_extractor=feature_extractor_stats), batched=True)
dataset_mean = np.mean(train_dataset['mean'])
dataset_std = np.mean(train_dataset['std'])
dataset_mean, dataset_std
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 from transformers import ASTFeatureExtractor
#       3 from datasets import load_dataset
# ----> 5 train_dataset = load_dataset("audiofolder", data_dir=train_path).get('train') # .shuffle(seed = 42)  # load the dataset and shuffle the examples
#       6 train_dataset = train_dataset.cast_column("audio", Audio(sampling_rate=MODEL_SAMPLING_RATE))
#       7 feature_extractor_stats = ASTFeatureExtractor.from_pretrained("MIT/ast-finetuned-audioset-10-10-0.4593", do_normalize=False)
#
# NameError: name 'train_path' is not defined

# %% [markdown]
# Using the <b>argparse</b> module in our training script, we can define the parameters that will be passed to the script. These parameters can include hyperparameters sent by the user, which are passed as command-line arguments to the script. Please go to the *baseline_ast_train.py* file located in the *src* and inspect the lines from 114 to 130, to see the whole list of possible arguments that you can pass to the script we've prepared.

# %%
hyperparameters={
    "epochs":10,                                                   # number of training epochs
    "patience":3,                                                  # early stopping - how many epoch without improvement will stop the training
    "train_batch_size":4,                                          # training batch size
    "model_name":"MIT/ast-finetuned-audioset-10-10-0.4593",        # name of the pretrained model from HuggingFace
    "train_dir":"train",                                           # folder name with training data
    "val_dir":"val",                                               # folder name with validation data
    "test_dir":"test",                                             # folder name with test data
    "train_dataset_mean":-8.141991150530815,                       # mean value of spectrograms of our resampled data 
    "train_dataset_std":4.095692486358449,                         # standard deviation value of spectrograms of our resampled data
    "learning_rate":2e-5,
    'test_oryginal_path':f's3://sagemaker-{DEFAULT_REGION}-{account_id}/oryginal_dataset/test',
    "sampling_rate": 22050
}

# %% [markdown]
# Finally, we need to specify which metrics we want Sagemaker to automatically track. For this, we need to set up [regular expressions](https://en.wikipedia.org/wiki/Regular_expression) that will be applied to the logs.
# The corresponding values will then be stored and made visible in the training job.

# %%
metric_definitions=[
    {'Name': 'loss', 'Regex': "'loss': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'learning_rate', 'Regex': "'learning_rate': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'eval_loss', 'Regex': "'eval_loss': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'eval_accuracy', 'Regex': "'eval_accuracy': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'eval_f1', 'Regex': "'eval_f1': ([0-9]+(.|e\-)[0-9]+),?"},
    #{'Name': 'eval_precision', 'Regex': "'eval_precision': ([0-9]+(.|e\-)[0-9]+),?"},
    #{'Name': 'eval_recall', 'Regex': "'eval_recall': ([0-9]+(.|e\-)[0-9]+),?"},
    {'Name': 'epoch', 'Regex': "'epoch': ([0-9]+(.|e\-)[0-9]+),?"}]

# %% [markdown]
# After all the necessary preparations, we are now ready to define a *SageMaker Estimator* which handles end-to-end Amazon SageMaker training and deployment tasks. While there are multiple available Estimators in SageMaker, we need to use the one that is compatible with our training script, so in our case, we will use the ```HuggingFace``` estimator.
#
# - SageMaker takes care of installing all the necessary libraries for the training job, but if there are any additional modules you want to use in the job, you can define them in ```src/requirements.txt```.
# - All the steps defined in our entry point will run during the training jobs. Therefore, if you want to change anything in the training process, you should define it in the Python script.
# - To start the job, we can call ```estimator.fit().``` With this command, the whole content of the src directory will be uploaded to the training instance. Therefore, if you want to use any additional functions, you should define them in src.
# - Note that interrupting the training job in the notebook won't stop it. If you don't want your job to finish, you have to stop it in the UI. Also, you can run only one job at a time.
# - When your training job is completed, your model will be stored as a .tar file in S3. The ```s3_output_location``` determines the location, and you can find it in the folder ```<your-training-job>/output```. You can download your model from there and test it locally. If there is no output folder, make sure to check the logs in the AWS console, as your training job may have failed.

# %%
import inspect
src_file_path = inspect.getfile(lambda: None)
print(src_file_path)
# Out:
# /tmp/ipykernel_29/2964946002.py

# %%
image_uri = '954362353459.dkr.ecr.us-east-1.amazonaws.com/sm-training-custom:latest'

huggingface_estimator = HuggingFace(
    entry_point=entry_point,                # fine-tuning script to use in training job
    source_dir=CURRENT_SCRIPT_FULL_PATH,           # directory where fine-tuning script is stored. This directory will be downloaded to training instance
    instance_type="ml.g4dn.xlarge",         # instance type - ml.g4dn.xlarge is a GPU instance so the training will be faster 
    output_path = s3_output_location,       # outputbucket to store our model after training
    instance_count=1,                       # number of instances. We are limited to 1 instance
    role=role,                              # IAM role used in training job to acccess AWS resources (S3)
    image_uri = image_uri,                  # passing our custom image with the required libraries
    py_version="py310",                     # Python version 
    hyperparameters=hyperparameters,        # hyperparameters to use in training job
    metric_definitions = metric_definitions # metrics we want to extract from logs. It will be visible in SageMaker training job UI
)

# %% [markdown]
# After we created the estimator, we will need to call the *fit* method to start the training job. As this might take a while, we can set ```wait=False``` so our notebook will not wait for the training job to finish and we can continue working, but for the sake of the tutorial let's set it to ```True```.

# %%
huggingface_estimator.fit(input_channels, wait=True)
# Out:
# Using provided s3_resource
# INFO:sagemaker:Creating training-job with name: sm-training-custom-2023-06-22-14-07-41-337
# 2023-06-22 14:07:41 Starting - Starting the training job...
# 2023-06-22 14:07:57 Starting - Preparing the instances for training......
# 2023-06-22 14:09:04 Downloading - Downloading input data...
# 2023-06-22 14:09:39 Training - Downloading the training image.........
# 2023-06-22 14:10:50 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-06-22 14:11:01,784 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-06-22 14:11:01,802 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-06-22 14:11:01,811 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-06-22 14:11:01,813 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-06-22 14:11:03,087 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-06-22 14:11:03,113 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-06-22 14:11:03,139 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2023-06-22 14:11:03,148 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "data": "/opt/ml/input/data/data"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.g4dn.xlarge",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "epochs": 10,
#         "learning_rate": 2e-05,
#         "model_name": "MIT/ast-finetuned-audioset-10-10-0.4593",
#         "patience": 3,
#         "sampling_rate": 22050,
#         "test_dir": "test",
#         "test_oryginal_path": "s3://sagemaker-us-east-1-292159885427/oryginal_dataset/test",
#         "train_batch_size": 4,
#         "train_dataset_mean": -8.141991150530815,
#         "train_dataset_std": 4.095692486358449,
#         "train_dir": "train",
#         "val_dir": "val"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "data": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.g4dn.xlarge",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "job_name": "sm-training-custom-2023-06-22-14-07-41-337",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-292159885427/sm-training-custom-2023-06-22-14-07-41-337/source/sourcedir.tar.gz",
#     "module_name": "baseline_ast_train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g4dn.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g4dn.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "baseline_ast_train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":10,"learning_rate":2e-05,"model_name":"MIT/ast-finetuned-audioset-10-10-0.4593","patience":3,"sampling_rate":22050,"test_dir":"test","test_oryginal_path":"s3://sagemaker-us-east-1-292159885427/oryginal_dataset/test","train_batch_size":4,"train_dataset_mean":-8.141991150530815,"train_dataset_std":4.095692486358449,"train_dir":"train","val_dir":"val"}
# SM_USER_ENTRY_POINT=baseline_ast_train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"data":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["data"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.g4dn.xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=baseline_ast_train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-292159885427/sm-training-custom-2023-06-22-14-07-41-337/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"data":"/opt/ml/input/data/data"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.g4dn.xlarge","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":10,"learning_rate":2e-05,"model_name":"MIT/ast-finetuned-audioset-10-10-0.4593","patience":3,"sampling_rate":22050,"test_dir":"test","test_oryginal_path":"s3://sagemaker-us-east-1-292159885427/oryginal_dataset/test","train_batch_size":4,"train_dataset_mean":-8.141991150530815,"train_dataset_std":4.095692486358449,"train_dir":"train","val_dir":"val"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"data":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"job_name":"sm-training-custom-2023-06-22-14-07-41-337","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-292159885427/sm-training-custom-2023-06-22-14-07-41-337/source/sourcedir.tar.gz","module_name":"baseline_ast_train","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"baseline_ast_train.py"}
# SM_USER_ARGS=["--epochs","10","--learning_rate","2e-05","--model_name","MIT/ast-finetuned-audioset-10-10-0.4593","--patience","3","--sampling_rate","22050","--test_dir","test","--test_oryginal_path","s3://sagemaker-us-east-1-292159885427/oryginal_dataset/test","--train_batch_size","4","--train_dataset_mean","-8.141991150530815","--train_dataset_std","4.095692486358449","--train_dir","train","--val_dir","val"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_DATA=/opt/ml/input/data/data
# SM_HP_EPOCHS=10
# SM_HP_LEARNING_RATE=2e-05
# SM_HP_MODEL_NAME=MIT/ast-finetuned-audioset-10-10-0.4593
# SM_HP_PATIENCE=3
# SM_HP_SAMPLING_RATE=22050
# SM_HP_TEST_DIR=test
# SM_HP_TEST_ORYGINAL_PATH=s3://sagemaker-us-east-1-292159885427/oryginal_dataset/test
# SM_HP_TRAIN_BATCH_SIZE=4
# SM_HP_TRAIN_DATASET_MEAN=-8.141991150530815
# SM_HP_TRAIN_DATASET_STD=4.095692486358449
# SM_HP_TRAIN_DIR=train
# SM_HP_VAL_DIR=val
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python310.zip:/opt/conda/lib/python3.10:/opt/conda/lib/python3.10/lib-dynload:/opt/conda/lib/python3.10/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.10 baseline_ast_train.py --epochs 10 --learning_rate 2e-05 --model_name MIT/ast-finetuned-audioset-10-10-0.4593 --patience 3 --sampling_rate 22050 --test_dir test --test_oryginal_path s3://sagemaker-us-east-1-292159885427/oryginal_dataset/test --train_batch_size 4 --train_dataset_mean -8.141991150530815 --train_dataset_std 4.095692486358449 --train_dir train --val_dir val
# 2023-06-22 14:11:03,171 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# 2023-06-22 14:11:06,635 - __main__ - INFO - Torch version
# 2023-06-22 14:11:06,635 - __main__ - INFO - 1.13.1+cu117
# 2023-06-22 14:11:06,635 - __main__ - INFO - Torch sees CUDA?
# 2023-06-22 14:11:06,656 - __main__ - INFO - True
# Downloading (…)rocessor_config.json:   0%|          | 0.00/297 [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json: 100%|██████████| 297/297 [00:00<00:00, 2.27MB/s]
# 2023-06-22 14:11:06,705 - __main__ - INFO -  feature extractor loaded with dataset mean: -8.141991150530815 and standard deviation: 4.095692486358449
# Resolving data files:   0%|          | 0/44 [00:00<?, ?it/s]
# Resolving data files: 100%|██████████| 44/44 [00:00<00:00, 152394.20it/s]
# Downloading and preparing dataset audiofolder/default to /root/.cache/huggingface/datasets/audiofolder/default-790d089216477e9d/0.0.0/6cbdd16f8688354c63b4e2a36e1585d05de285023ee6443ffd71c4182055c0fc...
# Downloading data files:   0%|          | 0/44 [00:00<?, ?it/s]
# Downloading data files: 100%|██████████| 44/44 [00:00<00:00, 66170.45it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset audiofolder downloaded and prepared to /root/.cache/huggingface/datasets/audiofolder/default-790d089216477e9d/0.0.0/6cbdd16f8688354c63b4e2a36e1585d05de285023ee6443ffd71c4182055c0fc. Subsequent calls will reuse this data.
# 0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 863.74it/s]
# 2023-06-22 14:11:06,833 - __main__ - INFO -  loaded train dataset length is: 43
# 2023-06-22 14:11:06,834 - __main__ - INFO -  train dataset sampling rate casted to: 22050
# Map:   0%|          | 0/43 [00:00<?, ? examples/s]
# Map:  74%|███████▍  | 32/43 [00:08<00:02,  3.68 examples/s]
# Map: 100%|██████████| 43/43 [00:09<00:00,  4.70 examples/s]
# 2023-06-22 14:11:16,552 - __main__ - INFO -  done extracting features for train dataset
# Resolving data files:   0%|          | 0/19 [00:00<?, ?it/s]
# Resolving data files: 100%|██████████| 19/19 [00:00<00:00, 21228.50it/s]
# Downloading and preparing dataset audiofolder/default to /root/.cache/huggingface/datasets/audiofolder/default-e982d9c1a8f461be/0.0.0/6cbdd16f8688354c63b4e2a36e1585d05de285023ee6443ffd71c4182055c0fc...
# Downloading data files:   0%|          | 0/19 [00:00<?, ?it/s]
# Downloading data files: 100%|██████████| 19/19 [00:00<00:00, 60926.43it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset audiofolder downloaded and prepared to /root/.cache/huggingface/datasets/audiofolder/default-e982d9c1a8f461be/0.0.0/6cbdd16f8688354c63b4e2a36e1585d05de285023ee6443ffd71c4182055c0fc. Subsequent calls will reuse this data.
# 0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 987.13it/s]
# 2023-06-22 14:11:16,632 - __main__ - INFO -  loaded validation dataset length is: 18
# 2023-06-22 14:11:16,636 - __main__ - INFO -  validation dataset sampling rate casted to: 22050
# Map:   0%|          | 0/18 [00:00<?, ? examples/s]
# Map: 100%|██████████| 18/18 [00:01<00:00, 15.90 examples/s]
# 2023-06-22 14:11:17,772 - __main__ - INFO -  done extracting features for validation dataset
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /opt/ml/code/baseline_ast_train.py:182 in <module>                           │
# │                                                                              │
# │   179 │   val_dataset_encoded = preprocess_data_for_training(dataset_path=va │
# │   180 │   │   │   │   │   │   │   │   │   │   │   │   │      fe_batch_size=a │
# │   181 │                                                                      │
# │ ❱ 182 │   test_dataset_encoded = preprocess_data_for_training(dataset_path=t │
# │   183 │   │   │   │   │   │   │   │   │   │   │   │   │   │   fe_batch_size= │
# │   184 │                                                                      │
# │   185 │   # Download model from model hub                                    │
# │                                                                              │
# │ /opt/ml/code/baseline_ast_train.py:75 in preprocess_data_for_training        │
# │                                                                              │
# │    72 │   │   dataset: The preprocessed dataset.                             │
# │    73 │                                                                      │
# │    74 │   """                                                                │
# │ ❱  75 │   dataset = load_dataset("audiofolder", data_dir=dataset_path).get(' │
# │    76 │                                                                      │
# │    77 │   # perform shuffle if specified                                     │
# │    78 │   if shuffle:                                                        │
# │                                                                              │
# │ /opt/conda/lib/python3.10/site-packages/datasets/load.py:1767 in             │
# │ load_dataset                                                                 │
# │                                                                              │
# │   1764 │   )                                                                 │
# │   1765 │                                                                     │
# │   1766 │   # Create a dataset builder                                        │
# │ ❱ 1767 │   builder_instance = load_dataset_builder(                          │
# │   1768 │   │   path=path,                                                    │
# │   1769 │   │   name=name,                                                    │
# │   1770 │   │   data_dir=data_dir,                                            │
# │                                                                              │
# │ /opt/conda/lib/python3.10/site-packages/datasets/load.py:1498 in             │
# │ load_dataset_builder                                                         │
# │                                                                              │
# │   1495 │   if use_auth_token is not None:                                    │
# │   1496 │   │   download_config = download_config.copy() if download_config e │
# │   1497 │   │   download_config.use_auth_token = use_auth_token               │
# │ ❱ 1498 │   dataset_module = dataset_module_factory(                          │
# │   1499 │   │   path,                                                         │
# │   1500 │   │   revision=revision,                                            │
# │   1501 │   │   download_config=download_config,                              │
# │                                                                              │
# │ /opt/conda/lib/python3.10/site-packages/datasets/load.py:1133 in             │
# │ dataset_module_factory                                                       │
# │                                                                              │
# │   1130 │   │   │   data_files=data_files,                                    │
# │   1131 │   │   │   download_config=download_config,                          │
# │   1132 │   │   │   download_mode=download_mode,                              │
# │ ❱ 1133 │   │   ).get_module()                                                │
# │   1134 │   # Try locally                                                     │
# │   1135 │   elif path.endswith(filename):                                     │
# │   1136 │   │   if os.path.isfile(path):                                      │
# │                                                                              │
# │ /opt/conda/lib/python3.10/site-packages/datasets/load.py:706 in get_module   │
# │                                                                              │
# │    703 │   def get_module(self) -> DatasetModule:                            │
# │    704 │   │   base_path = str(Path(self.data_dir).resolve()) if self.data_d │
# │    705 │   │   patterns = (                                                  │
# │ ❱  706 │   │   │   sanitize_patterns(self.data_files) if self.data_files is  │
# │    707 │   │   )                                                             │
# │    708 │   │   data_files = DataFilesDict.from_local_or_remote(              │
# │    709 │   │   │   patterns,                                                 │
# │                                                                              │
# │ /opt/conda/lib/python3.10/site-packages/datasets/data_files.py:461 in        │
# │ get_data_patterns_locally                                                    │
# │                                                                              │
# │   458 │   try:                                                               │
# │   459 │   │   return _get_data_files_patterns(resolver)                      │
# │   460 │   except FileNotFoundError:                                          │
# │ ❱ 461 │   │   raise EmptyDatasetError(f"The directory at {base_path} doesn't │
# │   462                                                                        │
# │   463                                                                        │
# │   464 def get_metadata_patterns_locally(base_path: str) -> List[str]:        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# EmptyDatasetError: The directory at
# /opt/ml/code/s3:/sagemaker-us-east-1-292159885427/oryginal_dataset/test doesn't
# contain any data files
# 2023-06-22 14:11:19,240 sagemaker-training-toolkit INFO     Waiting for the process to finish and give a return code.
# 2023-06-22 14:11:19,240 sagemaker-training-toolkit INFO     Done waiting for a return code. Received 1 from exiting process.
# 2023-06-22 14:11:19,241 sagemaker-training-toolkit ERROR    Reporting training FAILURE
# 2023-06-22 14:11:19,241 sagemaker-training-toolkit ERROR    ExecuteUserScriptError:
# ExitCode 1
# ErrorMessage "│   460 │   except FileNotFoundError:                                          │
#  │ ❱ 461 │   │   raise EmptyDatasetError(f"The directory at {base_path} doesn't │
#  │   462                                                                        │
#  │   463                                                                        │
#  │   464 def get_metadata_patterns_locally(base_path: str) -> List[str]:        │
#  ╰──────────────────────────────────────────────────────────────────────────────╯
#  EmptyDatasetError: The directory at
#  /opt/ml/code/s3:/sagemaker-us-east-1-292159885427/oryginal_dataset/test doesn't
#  contain any data files"
# Command "/opt/conda/bin/python3.10 baseline_ast_train.py --epochs 10 --learning_rate 2e-05 --model_name MIT/ast-finetuned-audioset-10-10-0.4593 --patience 3 --sampling_rate 22050 --test_dir test --test_oryginal_path s3://sagemaker-us-east-1-292159885427/oryginal_dataset/test --train_batch_size 4 --train_dataset_mean -8.141991150530815 --train_dataset_std 4.095692486358449 --train_dir train --val_dir val"
# 2023-06-22 14:11:19,241 sagemaker-training-toolkit ERROR    Encountered exit_code 1
#
# 2023-06-22 14:11:36 Uploading - Uploading generated training model
# 2023-06-22 14:11:36 Failed - Training job failed
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 huggingface_estimator.fit(input_channels, wait=True)
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/workflow/pipeline_context.py:284, in runnable_by_pipeline.<locals>.wrapper(*args, **kwargs)
#     280         return context
#     282     return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
# --> 284 return run_func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/estimator.py:1198, in EstimatorBase.fit(self, inputs, wait, logs, job_name, experiment_config)
#    1196 self.jobs.append(self.latest_training_job)
#    1197 if wait:
# -> 1198     self.latest_training_job.wait(logs=logs)
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/estimator.py:2344, in _TrainingJob.wait(self, logs)
#    2342 # If logs are requested, call logs_for_jobs.
#    2343 if logs != "None":
# -> 2344     self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    2345 else:
#    2346     self.sagemaker_session.wait_for_job(self.job_name)
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/session.py:4630, in Session.logs_for_job(self, job_name, wait, poll, log_type, timeout)
#    4609 def logs_for_job(self, job_name, wait=False, poll=10, log_type="All", timeout=None):
#    4610     """Display logs for a given training job, optionally tailing them until job is complete.
#    4611
#    4612     If the output is a tty or a Jupyter cell, it will be color-coded
#    (...)
#    4628         exceptions.UnexpectedStatusException: If waiting and the training job fails.
#    4629     """
# -> 4630     _logs_for_job(self.boto_session, job_name, wait, poll, log_type, timeout)
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/session.py:6492, in _logs_for_job(boto_session, job_name, wait, poll, log_type, timeout)
#    6489             last_profiler_rule_statuses = profiler_rule_statuses
#    6491 if wait:
# -> 6492     _check_job_status(job_name, description, "TrainingJobStatus")
#    6493     if dot:
#    6494         print()
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/session.py:6545, in _check_job_status(job, desc, status_key_name)
#    6539 if "CapacityError" in str(reason):
#    6540     raise exceptions.CapacityError(
#    6541         message=message,
#    6542         allowed_statuses=["Completed", "Stopped"],
#    6543         actual_status=status,
#    6544     )
# -> 6545 raise exceptions.UnexpectedStatusException(
#    6546     message=message,
#    6547     allowed_statuses=["Completed", "Stopped"],
#    6548     actual_status=status,
#    6549 )
#
# UnexpectedStatusException: Error for Training job sm-training-custom-2023-06-22-14-07-41-337: Failed. Reason: AlgorithmError: ExecuteUserScriptError:
# ExitCode 1
# ErrorMessage "│   460 │   except FileNotFoundError:                                          │
#  │ ❱ 461 │   │   raise EmptyDatasetError(f"The directory at {base_path} doesn't │
#  │   462                                                                        │
#  │   463                                                                        │
#  │   464 def get_metadata_patterns_locally(base_path: str) -> List[str]:        │
#  ╰──────────────────────────────────────────────────────────────────────────────╯
#  EmptyDatasetError: The directory at
#  /opt/ml/code/s3:/sagemaker-us-east-1-292159885427/oryginal_dataset/test doesn't
#  contain any data files"
# Command "/opt/conda/bin/python3.10 baseline_ast_train.py --epochs 10 --learning_rate 2e-05 --model_name MIT/ast-finetuned-audioset-10-10-0.4593 --patienc, exit code: 1

# %%
current_job_name = huggingface_estimator._hyperparameters["sagemaker_job_name"]
archive_solution_files(CURRENT_SCRIPT_FULL_PATH, current_job_name)

# %%
# save the model location to the filesystem so that we can use it later
model_location = f'{s3_output_location}/{huggingface_estimator._hyperparameters["sagemaker_job_name"]}/output/model.tar.gz'
print(model_location)

# %%
# saving the csv file under the appropriate location. Create the folder if it doesn't exist 
model_folder_path =f"models/{huggingface_estimator._hyperparameters['sagemaker_job_name']}"

if not os.path.exists(model_folder_path):
    os.makedirs(model_folder_path)
    
with open(f'{model_folder_path}/model_location.txt', 'w+') as f:
    f.write(model_location)

# %% [markdown]
# One important question that we haven't answered to far is *How can I see how the training is doing?* After all you need see if there are any issues or if the training is going well.
# This can be done as follows:
#
# 1. Go to the AWS Console
# 2. Search for AWS Sagemaker and go to the Service
# 3. On the left panel click on Training -> Training Jobs
# 4. Your training job should the one at the very top. Click it.
# 5. The details page has a link *View logs* in the *Monitor* section (scroll down). Click this to see the logs.
#
# The default configuration for this tutorial will train your model for approximately 7 epochs. This should take less than 2 hours and give you an indication if an idea is working or not.
# Training for longer does not necessary help. **To save time and money we suggest to start with a few epochs and only train models for longer where you are certain that there is a significant benefit.** After all, you only have a limited budget.

# %% [markdown]
# ## Key takeaways:
#
# - We utilize **SageMaker Training jobs** to train our model, which takes place on a separate virtual machine (instance). The steps outlined in the training script (baseline_ast_train.py) will be executed there. If you wish to alter the training process, modify the training script accordingly (and we'd suggest you to save it under a new name).
# - You can monitor the job's progress in the [*SageMaker Trainings UI*]('https://us-east-1.console.aws.amazon.com/sagemaker/home?region=us-east-1#/jobs'). In the **Monitoring** section, you can keep track of metrics during the training process.
# - If you want to stop the training, you must do so in the [*SageMaker Trainings UI*]('https://us-east-1.console.aws.amazon.com/sagemaker/home?region=us-east-1#/jobs'). Stopping the job in the notebook alone will not suffice.
# - You can alter the input data to use your own S3 bucket if you have created the dataset differently.
# - Keep in mind that you can experiment with the **hyperparameters** of the model.
# - Since we employ a GPU instance for the training process, bear in mind that we pay for each second of training. If you do not see any improvement in longer trainings (more epochs), focus on other tasks such as data preprocessing.

# %% [markdown]
# # A new submission with our newly trained model!
#
# After the training job is finished - which should take in our case less than 2 hours! - you can download the results of the training job.
#
# *Note: Check the AWS training job console to see the status of your training job*
#
# First we need to specify where the results where stored. We stored the model location to the local filesystem, we only need to read it. If that didn't work, make sure to check the Sagemaker Training section in the AWS console. The model location will look similar to this:```s3://sagemaker-us-east-1-192475648101/train/huggingface-pytorch-training-2023-05-05-13-44-42-427/output/model.tar.gz```

# %%
# read the model location from the filesystem
with open(f'{model_folder_path}/model_location.txt', 'r') as f:
    model_location = f.read()

# %% [markdown]
# We prepared a custom function that downloads the results to our local directory.

# %%
local_model_dir = download_and_extract_model(model_uri=model_location, local_dir='models')
local_model_dir

# %% [markdown]
# To confirm that everything ran correctly, please navigate to the *models* directory. There, you should find the following files:
#
# - *checkpoint-###* folders
# - *prediction_val.csv*
# - *prediction_test.csv*
# - *model.tar.gz*
#
# The checkpoint folders contain the model's weights, which can be loaded to generate predictions from different epochs. In the training script, we set ```load_best_model_at_end``` to **True**, which ensures that the model is loaded with the best checkpoint based on the validation loss. After loading the checkpoint, we generated predictions for both the validation and test sets, which can be found in the same directory where you extracted the model.
#
# With everything set up, let's proceed to loading the test set predictions!

# %%
test_preds = pd.read_csv(f'{local_model_dir}/prediction_test.csv', index_col = False)
test_preds.head()

# %% [markdown]
# You can upload this file to the [GDSC website](https://gdsc.ce.capgemini.com/) what score did you get? Do you see a big difference between this model and the one trained on a small sample of data?
#
# Please keep in mind that the submission file must adhere to the following format:
#
# - A *file_name* column, indicating the file for which the prediction was generated
# - A *predicted_class_id* column, containing the predicted ID for that file.
#
# **If the submission file deviates from this format, there is a risk of encountering problems when running the evaluation function.**

# %% [markdown]
# # Error analysis on Validation set
#
# Error analysis is an essential part of machine learning, as it helps us to identify and diagnose problems that may arise during the training and testing stages of a machine learning model. By analyzing the errors, we can gain insights into the performance of the model, and we can make informed decisions about how to improve its accuracy and effectiveness.
#
# There are several reasons why error analysis is necessary in machine learning and how can it help with improving model performance:
#
# - Identify the sources of errors: By analyzing the errors, we can identify the sources of errors, such as data quality issues. This helps us to understand where the model is failing and how we can improve it.
#
# - Improve model accuracy: Error analysis can help us to fine-tune the model by identifying which features or parameters are causing errors, and adjusting them to improve accuracy.
#
# - Evaluate model performance: Error analysis helps us to evaluate the performance of the model against the desired outcome. It also allows us to compare the performance of different models and select the best one for our use case.
#
# As we prepared predictions on the validation set we can use them for the error analysis. Let's give it a try!
#
#
# First of all we should load ```prediction_val.csv``` file and inspect it

# %%
val_preds = pd.read_csv(f'{local_model_dir}/prediction_val.csv', index_col = False)
val_preds.head()

# %% [markdown]
# This dataframe contains two additional columns that will be useful for Error Analysis:
#
# - label - the ground truth label
# - loss - the degree to which the model's prediction differs from the actual class

# %% [markdown]
# Before looking in depth at the loss values let's use our function imported from the *gdsc_eval.py* module to generate a **Confusion matrix** plot, which will provide greater insight into the model's performance for specific classes.
#
# Note from the docstring in the *gdsc_eval.py* that the last argument tells us if we want to normalize the values of the matrix over the true labels, predicted labels, the whole population or just give absolute values. Try to plot the confusion matrix with different normalizations and see if you can understand what do they mean. If you feel like something is not clear - post a comment on the Team's channel and start a conversation!

# %%
plot_confusion_matrix(val_preds['label'], val_preds['predicted_class_id'], normalize=None)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from results_utils import persist_confusion_matrix

persist_confusion_matrix(val_preds['label'], val_preds['predicted_class_id'], normalize=None, file_prefix='valid')

# %% [markdown]
# While the majority of the classes are accurately classified, there are a few that remain misclassified. Additionally, the model appears to have difficulty distinguishing between certain classes, would you be able to identify them? Maybe they are similar to each other?
#
# We will now examine the losses for individual predictions. Generally speaking, the model's confidence in a given prediction increases as the loss decreases. Let's see which are the top 10 classes with the highest loss values!

# %%
# Classes sorted by the highest sum of loss
(
    val_preds.groupby("label")[["loss"]]
    .agg(["count", "mean", "sum"])
    .droplevel(level=0, axis=1)  # Get rid of multi-level columns
    .sort_values(by="sum", ascending=False)
    .reset_index()
    .round(2)
    .head(10)
    .T
)

# %% [markdown]
# Since we only have a limited number of examples for certain classes, it might be more meaningful to focus on the average loss value instead. This approach could provide a more accurate representation of the model's performance for those classes with minimal validation examples.

# %%
# Classes sorted by highest mean of loss
(
    val_preds.groupby("label")[["loss"]]
    .agg(["count", "mean", "sum"])
    .droplevel(level=0, axis=1)
    .sort_values(by="mean", ascending=False)
    .reset_index()
    .round(2)
    .head(10)
    .T
)

# %% [markdown]
# The above tables give us an idea which classes are the most problematic. To investigate this further, we suggest plotting the examples with the highest loss and some of the examples of the class that the files were missclassified with. Try to identify any patterns or issues within the data. It is possible that this could be related to the quality of the data, and further analysis may be required.

# %% [markdown]
# ## Exercises:
#
# - Conduct your own Error Analysis based on the validation dataset predictions. Explore classes with the highest and lowest losses, and visualize spectrograms of these classes using the functions from the 2nd tutorial on EDA. Identify any classes that the model is consistently misclassifying and investigate whether these classes are similar to each other.
# - Experiment with different hyperparameters during the training process to see how they affect model performance.
# - Check out the [HuggingFace model Hub]('https://huggingface.co/models?pipeline_tag=audio-classification&sort=downloads'), where you can test out various audio classification models.

# %% [markdown]
# # What's next?
#
# Phew! That was a long journey! From analyzing the metadata to getting first results. But the work is not yet done - honestly it has just started! You may wonder how to improve the results we have obtained. Well, there are few possibilities:
#
# ## Different preprocessing
#
# Maybe it's worth to go back to the documentation of the [ASTFeatureExtractor](https://huggingface.co/docs/transformers/main/en/model_doc/audio-spectrogram-transformer#transformers.ASTFeatureExtractor). There are some hyperparameters that you can tweak like *max_length* of the file taken as the input.
#
# ## Data Augmentation
#
# In the gdsc docker image provided by us you will find libraries like [torchaudio](https://pytorch.org/audio/stable/index.html) and [librosa](https://librosa.org/doc/main/index.html). Thsoe serve you the purpose of augmenting your dataset with use of various preprocessing steps. Maybe after inspecting the missclassifications you will come up with different methods for tweaking some audio features of the arrays?
#
# Just please note that only the torchaudio library works with GPU, librosa will work only with CPU, which will make your training much slower.
#
# ## Other models
#
# The AST model is not the only one out there. Try to inspect other architectures. Maybe one of them will be the winning one! Here are two example sources you can inspect (feel free to find more!):
#
# #### Hugging Face Model Hub
#
# The [Hugging Face Model Hub](https://huggingface.co/models?pipeline_tag=audio-classification&sort=downloads) has a variety of different models. Try to inspect few of them.
#
# #### Papers with code
#
# The Papers with code site offers benchmarks of different models on different datasets. Here is an example of [benchmarking models on AudioSet dataset](https://paperswithcode.com/sota/audio-classification-on-audioset). This may be a bit advanced, but you can try to implement the code found in the repositories for a model that gives high scores.
