# %%
import logging                                                    # module for displaying relevant information in the logs
import sys                                                        # to access to some variables used or maintained by the interpreter 
import argparse                                                   # to parse arguments from passed in the hyperparameters
import os                                                         # to manage environmental variables
import json                                                       # to open the json file with labels
from transformers import (                                        # required classes to perform the model training and implement early stopping
    ASTFeatureExtractor, 
    ASTForAudioClassification, 
    Trainer, 
    TrainingArguments, 
    EarlyStoppingCallback
)                                    
import torch                                                       # library to work with PyTorch tensors and to figure out if we have a GPU available
from datasets import load_dataset, Audio, Dataset                  # required tools to create, load and process our audio dataset
import pandas as pd                                                # home of the DataFrame construct, _the_ most important object for Data Science
from preprocessing import preprocess_audio_arrays                  # functions to preprocess the dataset with ASTFeatureExtractor
from gdsc_eval import compute_metrics, make_predictions, make_chunked_predictions           # functions to create predictions and evaluate them
from typing import Optional                                        # for type hints
                                # Add the source directory to the PYTHONPATH. This allows to import local functions and modules.
from config import DEFAULT_BUCKET, DEFAULT_REGION

# %%
# CONFIG

#----- BEST MODEL ---------
#7 sec, sr=44100, lr=2e-05, num_mel_bins=178

SAMPLING_RATE = 44100

SPLIT_IN_SECS = 7  # in seconds
CHUNK_MIN_SIZE = 1  # in seconds

model_name = 'sm-training-custom-2023-07-16-14-12-31-154'
checkpoint = 'checkpoint-13200'

FOLDER_TO_PROCESS = 'test'

# %%
model_path =f"/root/data/experiments/models/{model_name}/{checkpoint}"

feature_extractor = ASTFeatureExtractor.from_pretrained(model_path)
model = ASTForAudioClassification.from_pretrained(model_path)

# %%
test_path = f'/root/data/data/{FOLDER_TO_PROCESS}'
test_dataset = load_dataset("audiofolder", data_dir=test_path).get('train')
test_dataset = test_dataset.cast_column("audio", Audio(sampling_rate=SAMPLING_RATE))
print(test_dataset)
print(test_dataset[0])
# Out:
# Resolving data files:   0%|          | 0/557 [00:00<?, ?it/s]
# Downloading and preparing dataset audiofolder/default to /root/.cache/huggingface/datasets/audiofolder/default-2d285a18baf538c5/0.0.0/6cbdd16f8688354c63b4e2a36e1585d05de285023ee6443ffd71c4182055c0fc...
# Downloading data files:   0%|          | 0/557 [00:00<?, ?it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset audiofolder downloaded and prepared to /root/.cache/huggingface/datasets/audiofolder/default-2d285a18baf538c5/0.0.0/6cbdd16f8688354c63b4e2a36e1585d05de285023ee6443ffd71c4182055c0fc. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset({
#     features: ['audio'],
#     num_rows: 556
# })
# {'audio': {'path': '/root/data/data/test/0.wav', 'array': array([ 0.        ,  0.        ,  0.        , ...,  0.06658936,
#         0.02105713, -0.00656128]), 'sampling_rate': 44100}}

# %%
remove_metadata = lambda x: x.endswith(".wav")
extract_file_name = lambda x: x.split('/')[-1]

test_paths = list(test_dataset.info.download_checksums.keys())

test_paths = list(filter(remove_metadata, test_paths))
test_paths = list(map(extract_file_name, test_paths))
print(test_paths[:3])

test_dataset = test_dataset.add_column("file_name", test_paths)
print(test_dataset)
print(test_dataset[0])
# Out:
# ['0.wav', '1.wav', '10.wav']
# Dataset({
#     features: ['audio', 'file_name'],
#     num_rows: 556
# })
# {'audio': {'path': '/root/data/data/test/0.wav', 'array': array([ 0.        ,  0.        ,  0.        , ...,  0.06658936,
#         0.02105713, -0.00656128]), 'sampling_rate': 44100}, 'file_name': '0.wav'}

# %%
import copy
from datasets import Dataset

chunks = []
total = 0
for i, x in enumerate(test_dataset):
    
    one_file_dataset = test_dataset.select([i])
    
    #print(x)
    file_size = len(x['audio']['array'])
    #print('file_size:', file_size)
    sampling_rate = x['audio']['sampling_rate']
    #print('sampling_rate:', sampling_rate)
    
    chunk_size = SPLIT_IN_SECS * sampling_rate
    n = int(file_size / chunk_size)
    num = 0
    for i_n in range(n+1):
        if i_n > 0 and len(x['audio']['array'][i_n * chunk_size : (i_n + 1) * chunk_size]) < CHUNK_MIN_SIZE * sampling_rate:
            break
            
        #print('chunk:', i_n)
        x_chunk = copy.deepcopy(x)
        x_chunk['audio']['array'] = x_chunk['audio']['array'][i_n * chunk_size : (i_n + 1) * chunk_size]
        #print(x_chunk['audio']['array'])
        
        one_file_dataset.add_item(x_chunk)
        chunks.append(x_chunk)
        num += 1
        total += 1
    
    print(f'{x["file_name"]} - file_size:{file_size} - splitted into {num} chunks')
    
    #if i > 10:
    #    break
            
print(f'finished chunking, total number of chunks: {total}')
chunked_one_file_dataset = Dataset.from_pandas(pd.DataFrame(chunks))
print('chunked_one_file_dataset:', chunked_one_file_dataset)
    

print('\npreprocessing by preprocess_audio_arrays ...')
chunked_one_file_dataset_encoded = chunked_one_file_dataset.map(lambda x: preprocess_audio_arrays(x, 'audio', 'array', feature_extractor), remove_columns="audio", batched=True, batch_size = 16)
chunked_one_file_dataset_encoded.set_format(type='torch', columns=['input_values'])
    
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


print('\ncalculating predictions by make_chunked_predictions ...')
chunked_one_file_dataset_encoded = chunked_one_file_dataset_encoded.map(lambda x: make_chunked_predictions(x['input_values'], model, device), batched=True, batch_size=16, remove_columns="input_values")
    
chunked_one_file_dataset_encoded_df = chunked_one_file_dataset_encoded.to_pandas()
print('\npredictions:', chunked_one_file_dataset_encoded_df, '\n\n')
chunked_one_file_dataset_encoded_df.to_csv(f"/root/data/experiments/models/{model_name}/{checkpoint}/predictions_{FOLDER_TO_PROCESS}_{SPLIT_IN_SECS}_secs_{SAMPLING_RATE}.csv", index=False)
chunked_one_file_dataset_encoded_df.to_csv(f"/root/data/experiments/exp_2023-07-13_chunk_fixed_predictions/predictions_{model_name}_{checkpoint}_{FOLDER_TO_PROCESS}_{SPLIT_IN_SECS}_secs_{SAMPLING_RATE}.csv", index=False)
print('RESULTS SAVED in:')
print(f"/root/data/experiments/models/{model_name}/{checkpoint}/predictions_{FOLDER_TO_PROCESS}_{SPLIT_IN_SECS}_secs_{SAMPLING_RATE}.csv")
print(f"/root/data/experiments/exp_2023-07-13_chunk_fixed_predictions/predictions_{model_name}_{checkpoint}_{FOLDER_TO_PROCESS}_{SPLIT_IN_SECS}_secs_{SAMPLING_RATE}.csv")
# Out:
# 0.wav - file_size:406784 - splitted into 2 chunks
# 1.wav - file_size:147375 - splitted into 1 chunks
# 10.wav - file_size:366303 - splitted into 2 chunks
# 100.wav - file_size:490633 - splitted into 2 chunks
# 101.wav - file_size:3174534 - splitted into 11 chunks
# 102.wav - file_size:264600 - splitted into 1 chunks
# 103.wav - file_size:176400 - splitted into 1 chunks
# 104.wav - file_size:846667 - splitted into 3 chunks
# 105.wav - file_size:264600 - splitted into 1 chunks
# 106.wav - file_size:529200 - splitted into 2 chunks
# 107.wav - file_size:220500 - splitted into 1 chunks
# 108.wav - file_size:1058400 - splitted into 4 chunks
# 109.wav - file_size:308700 - splitted into 1 chunks
# 11.wav - file_size:485100 - splitted into 2 chunks
# 110.wav - file_size:264600 - splitted into 1 chunks
# 111.wav - file_size:88200 - splitted into 1 chunks
# 112.wav - file_size:2295459 - splitted into 8 chunks
# 113.wav - file_size:7943344 - splitted into 26 chunks
# 114.wav - file_size:441000 - splitted into 2 chunks
# 115.wav - file_size:4189500 - splitted into 14 chunks
# 116.wav - file_size:423060 - splitted into 2 chunks
# 117.wav - file_size:220500 - splitted into 1 chunks
# 118.wav - file_size:88200 - splitted into 1 chunks
# 119.wav - file_size:1014300 - splitted into 4 chunks
# 12.wav - file_size:2593481 - splitted into 9 chunks
# 120.wav - file_size:599114 - splitted into 2 chunks
# 121.wav - file_size:295037 - splitted into 1 chunks
# 122.wav - file_size:132300 - splitted into 1 chunks
# 123.wav - file_size:88200 - splitted into 1 chunks
# 124.wav - file_size:594944 - splitted into 2 chunks
# 125.wav - file_size:441000 - splitted into 2 chunks
# 126.wav - file_size:3161780 - splitted into 11 chunks
# 127.wav - file_size:617400 - splitted into 2 chunks
# 128.wav - file_size:132300 - splitted into 1 chunks
# 129.wav - file_size:441000 - splitted into 2 chunks
# 13.wav - file_size:3019149 - splitted into 10 chunks
# 130.wav - file_size:264600 - splitted into 1 chunks
# 131.wav - file_size:176400 - splitted into 1 chunks
# 132.wav - file_size:617400 - splitted into 2 chunks
# 133.wav - file_size:5258232 - splitted into 17 chunks
# 134.wav - file_size:800316 - splitted into 3 chunks
# 135.wav - file_size:132300 - splitted into 1 chunks
# 136.wav - file_size:1014300 - splitted into 4 chunks
# 137.wav - file_size:705600 - splitted into 3 chunks
# 138.wav - file_size:352800 - splitted into 2 chunks
# 139.wav - file_size:485100 - splitted into 2 chunks
# 14.wav - file_size:749700 - splitted into 3 chunks
# 140.wav - file_size:926100 - splitted into 3 chunks
# 141.wav - file_size:132300 - splitted into 1 chunks
# 142.wav - file_size:4241859 - splitted into 14 chunks
# 143.wav - file_size:705600 - splitted into 3 chunks
# 144.wav - file_size:617400 - splitted into 2 chunks
# 145.wav - file_size:132300 - splitted into 1 chunks
# 146.wav - file_size:926100 - splitted into 3 chunks
# 147.wav - file_size:2646000 - splitted into 9 chunks
# 148.wav - file_size:1323000 - splitted into 5 chunks
# 149.wav - file_size:88200 - splitted into 1 chunks
# 15.wav - file_size:352800 - splitted into 2 chunks
# 150.wav - file_size:1234800 - splitted into 4 chunks
# 151.wav - file_size:1543500 - splitted into 5 chunks
# 152.wav - file_size:220500 - splitted into 1 chunks
# 153.wav - file_size:132300 - splitted into 1 chunks
# 154.wav - file_size:149940 - splitted into 1 chunks
# 155.wav - file_size:485100 - splitted into 2 chunks
# 156.wav - file_size:612791 - splitted into 2 chunks
# 157.wav - file_size:919534 - splitted into 3 chunks
# 158.wav - file_size:749700 - splitted into 3 chunks
# 159.wav - file_size:2646000 - splitted into 9 chunks
# 16.wav - file_size:661500 - splitted into 3 chunks
# 160.wav - file_size:2615584 - splitted into 9 chunks
# 161.wav - file_size:441000 - splitted into 2 chunks
# 162.wav - file_size:88200 - splitted into 1 chunks
# 163.wav - file_size:277830 - splitted into 1 chunks
# 164.wav - file_size:559377 - splitted into 2 chunks
# 165.wav - file_size:185220 - splitted into 1 chunks
# 166.wav - file_size:802921 - splitted into 3 chunks
# 167.wav - file_size:1935279 - splitted into 7 chunks
# 168.wav - file_size:974610 - splitted into 4 chunks
# 169.wav - file_size:277831 - splitted into 1 chunks
# 17.wav - file_size:308700 - splitted into 1 chunks
# 170.wav - file_size:132300 - splitted into 1 chunks
# 171.wav - file_size:171990 - splitted into 1 chunks
# 172.wav - file_size:441000 - splitted into 2 chunks
# 173.wav - file_size:458640 - splitted into 2 chunks
# 174.wav - file_size:1102500 - splitted into 4 chunks
# 175.wav - file_size:2762761 - splitted into 9 chunks
# 176.wav - file_size:434914 - splitted into 2 chunks
# 177.wav - file_size:2028600 - splitted into 7 chunks
# 178.wav - file_size:1957656 - splitted into 7 chunks
# 179.wav - file_size:308700 - splitted into 1 chunks
# 18.wav - file_size:4718700 - splitted into 16 chunks
# 180.wav - file_size:643659 - splitted into 2 chunks
# 181.wav - file_size:220500 - splitted into 1 chunks
# 182.wav - file_size:2601900 - splitted into 9 chunks
# 183.wav - file_size:749700 - splitted into 3 chunks
# 184.wav - file_size:44100 - splitted into 1 chunks
# 185.wav - file_size:970200 - splitted into 4 chunks
# 186.wav - file_size:749700 - splitted into 3 chunks
# 187.wav - file_size:110250 - splitted into 1 chunks
# 188.wav - file_size:167580 - splitted into 1 chunks
# 189.wav - file_size:443520 - splitted into 2 chunks
# 19.wav - file_size:3556674 - splitted into 12 chunks
# 190.wav - file_size:132300 - splitted into 1 chunks
# 191.wav - file_size:749700 - splitted into 3 chunks
# 192.wav - file_size:176400 - splitted into 1 chunks
# 193.wav - file_size:1455039 - splitted into 5 chunks
# 194.wav - file_size:663040 - splitted into 3 chunks
# 195.wav - file_size:1234800 - splitted into 4 chunks
# 196.wav - file_size:1587600 - splitted into 6 chunks
# 197.wav - file_size:828800 - splitted into 3 chunks
# 198.wav - file_size:882000 - splitted into 3 chunks
# 199.wav - file_size:967529 - splitted into 3 chunks
# 2.wav - file_size:1940400 - splitted into 7 chunks
# 20.wav - file_size:617400 - splitted into 2 chunks
# 200.wav - file_size:573300 - splitted into 2 chunks
# 201.wav - file_size:308700 - splitted into 1 chunks
# 202.wav - file_size:441000 - splitted into 2 chunks
# 203.wav - file_size:705600 - splitted into 3 chunks
# 204.wav - file_size:308700 - splitted into 1 chunks
# 205.wav - file_size:566272 - splitted into 2 chunks
# 206.wav - file_size:608579 - splitted into 2 chunks
# 207.wav - file_size:485100 - splitted into 2 chunks
# 208.wav - file_size:352800 - splitted into 2 chunks
# 209.wav - file_size:1234800 - splitted into 4 chunks
# 21.wav - file_size:934920 - splitted into 3 chunks
# 210.wav - file_size:195985 - splitted into 1 chunks
# 211.wav - file_size:1024956 - splitted into 4 chunks
# 212.wav - file_size:352800 - splitted into 2 chunks
# 213.wav - file_size:2447379 - splitted into 8 chunks
# 214.wav - file_size:3087000 - splitted into 10 chunks
# 215.wav - file_size:1234800 - splitted into 4 chunks
# 216.wav - file_size:4246263 - splitted into 14 chunks
# 217.wav - file_size:441000 - splitted into 2 chunks
# 218.wav - file_size:88200 - splitted into 1 chunks
# 219.wav - file_size:1211274 - splitted into 4 chunks
# 22.wav - file_size:798624 - splitted into 3 chunks
# 220.wav - file_size:578910 - splitted into 2 chunks
# 221.wav - file_size:308700 - splitted into 1 chunks
# 222.wav - file_size:1116095 - splitted into 4 chunks
# 223.wav - file_size:1190700 - splitted into 4 chunks
# 224.wav - file_size:441000 - splitted into 2 chunks
# 225.wav - file_size:132300 - splitted into 1 chunks
# 226.wav - file_size:485100 - splitted into 2 chunks
# 227.wav - file_size:88200 - splitted into 1 chunks
# 228.wav - file_size:1675800 - splitted into 6 chunks
# 229.wav - file_size:4057200 - splitted into 14 chunks
# 23.wav - file_size:3864480 - splitted into 13 chunks
# 230.wav - file_size:441000 - splitted into 2 chunks
# 231.wav - file_size:176400 - splitted into 1 chunks
# 232.wav - file_size:1146600 - splitted into 4 chunks
# 233.wav - file_size:1984500 - splitted into 7 chunks
# 234.wav - file_size:1986814 - splitted into 7 chunks
# 235.wav - file_size:696780 - splitted into 3 chunks
# 236.wav - file_size:960000 - splitted into 3 chunks
# 237.wav - file_size:3802974 - splitted into 13 chunks
# 238.wav - file_size:88200 - splitted into 1 chunks
# 239.wav - file_size:211456 - splitted into 1 chunks
# 24.wav - file_size:507150 - splitted into 2 chunks
# 240.wav - file_size:529200 - splitted into 2 chunks
# 241.wav - file_size:837900 - splitted into 3 chunks
# 242.wav - file_size:1881792 - splitted into 6 chunks
# 243.wav - file_size:529200 - splitted into 2 chunks
# 244.wav - file_size:3307500 - splitted into 11 chunks
# 245.wav - file_size:705600 - splitted into 3 chunks
# 246.wav - file_size:507150 - splitted into 2 chunks
# 247.wav - file_size:321930 - splitted into 1 chunks
# 248.wav - file_size:174635 - splitted into 1 chunks
# 249.wav - file_size:430080 - splitted into 2 chunks
# 25.wav - file_size:1623552 - splitted into 6 chunks
# 250.wav - file_size:145530 - splitted into 1 chunks
# 251.wav - file_size:333312 - splitted into 1 chunks
# 252.wav - file_size:264600 - splitted into 1 chunks
# 253.wav - file_size:88200 - splitted into 1 chunks
# 254.wav - file_size:264600 - splitted into 1 chunks
# 255.wav - file_size:132300 - splitted into 1 chunks
# 256.wav - file_size:2371419 - splitted into 8 chunks
# 257.wav - file_size:61741 - splitted into 1 chunks
# 258.wav - file_size:3403506 - splitted into 11 chunks
# 259.wav - file_size:125440 - splitted into 1 chunks
# 26.wav - file_size:176400 - splitted into 1 chunks
# 260.wav - file_size:864779 - splitted into 3 chunks
# 261.wav - file_size:88200 - splitted into 1 chunks
# 262.wav - file_size:705600 - splitted into 3 chunks
# 263.wav - file_size:1631700 - splitted into 6 chunks
# 264.wav - file_size:780000 - splitted into 3 chunks
# 265.wav - file_size:176400 - splitted into 1 chunks
# 266.wav - file_size:9021342 - splitted into 30 chunks
# 267.wav - file_size:202860 - splitted into 1 chunks
# 268.wav - file_size:1190700 - splitted into 4 chunks
# 269.wav - file_size:132300 - splitted into 1 chunks
# 27.wav - file_size:220500 - splitted into 1 chunks
# 270.wav - file_size:617400 - splitted into 2 chunks
# 271.wav - file_size:132300 - splitted into 1 chunks
# 272.wav - file_size:396900 - splitted into 2 chunks
# 273.wav - file_size:1021952 - splitted into 4 chunks
# 274.wav - file_size:2734200 - splitted into 9 chunks
# 275.wav - file_size:3219300 - splitted into 11 chunks
# 276.wav - file_size:251370 - splitted into 1 chunks
# 277.wav - file_size:352800 - splitted into 2 chunks
# 278.wav - file_size:176400 - splitted into 1 chunks
# 279.wav - file_size:3572100 - splitted into 12 chunks
# 28.wav - file_size:426496 - splitted into 2 chunks
# 280.wav - file_size:2072700 - splitted into 7 chunks
# 281.wav - file_size:573300 - splitted into 2 chunks
# 282.wav - file_size:3275960 - splitted into 11 chunks
# 283.wav - file_size:1896300 - splitted into 7 chunks
# 284.wav - file_size:793800 - splitted into 3 chunks
# 285.wav - file_size:354816 - splitted into 2 chunks
# 286.wav - file_size:176400 - splitted into 1 chunks
# 287.wav - file_size:352800 - splitted into 2 chunks
# 288.wav - file_size:132300 - splitted into 1 chunks
# 289.wav - file_size:1948839 - splitted into 7 chunks
# 29.wav - file_size:176400 - splitted into 1 chunks
# 290.wav - file_size:88200 - splitted into 1 chunks
# 291.wav - file_size:594944 - splitted into 2 chunks
# 292.wav - file_size:264600 - splitted into 1 chunks
# 293.wav - file_size:264737 - splitted into 1 chunks
# 294.wav - file_size:4410000 - splitted into 15 chunks
# 295.wav - file_size:988020 - splitted into 4 chunks
# 296.wav - file_size:1543500 - splitted into 5 chunks
# 297.wav - file_size:2205000 - splitted into 8 chunks
# 298.wav - file_size:1452639 - splitted into 5 chunks
# 299.wav - file_size:141966 - splitted into 1 chunks
# 3.wav - file_size:1852200 - splitted into 6 chunks
# 30.wav - file_size:1058400 - splitted into 4 chunks
# 300.wav - file_size:2536957 - splitted into 9 chunks
# 301.wav - file_size:180810 - splitted into 1 chunks
# 302.wav - file_size:526482 - splitted into 2 chunks
# 303.wav - file_size:2205000 - splitted into 8 chunks
# 304.wav - file_size:194040 - splitted into 1 chunks
# 305.wav - file_size:1146600 - splitted into 4 chunks
# 306.wav - file_size:4974750 - splitted into 16 chunks
# 307.wav - file_size:176400 - splitted into 1 chunks
# 308.wav - file_size:529200 - splitted into 2 chunks
# 309.wav - file_size:529200 - splitted into 2 chunks
# 31.wav - file_size:132300 - splitted into 1 chunks
# 310.wav - file_size:264600 - splitted into 1 chunks
# 311.wav - file_size:2638899 - splitted into 9 chunks
# 312.wav - file_size:485100 - splitted into 2 chunks
# 313.wav - file_size:202860 - splitted into 1 chunks
# 314.wav - file_size:286650 - splitted into 1 chunks
# 315.wav - file_size:66150 - splitted into 1 chunks
# 316.wav - file_size:136710 - splitted into 1 chunks
# 317.wav - file_size:926100 - splitted into 3 chunks
# 318.wav - file_size:749700 - splitted into 3 chunks
# 319.wav - file_size:308700 - splitted into 1 chunks
# 32.wav - file_size:176400 - splitted into 1 chunks
# 320.wav - file_size:1807599 - splitted into 6 chunks
# 321.wav - file_size:1852200 - splitted into 6 chunks
# 322.wav - file_size:3528000 - splitted into 12 chunks
# 323.wav - file_size:511560 - splitted into 2 chunks
# 324.wav - file_size:2028600 - splitted into 7 chunks
# 325.wav - file_size:264600 - splitted into 1 chunks
# 326.wav - file_size:44100 - splitted into 1 chunks
# 327.wav - file_size:573300 - splitted into 2 chunks
# 328.wav - file_size:206136 - splitted into 1 chunks
# 329.wav - file_size:1323000 - splitted into 5 chunks
# 33.wav - file_size:529200 - splitted into 2 chunks
# 330.wav - file_size:88200 - splitted into 1 chunks
# 331.wav - file_size:617400 - splitted into 2 chunks
# 332.wav - file_size:440549 - splitted into 2 chunks
# 333.wav - file_size:653472 - splitted into 2 chunks
# 334.wav - file_size:176400 - splitted into 1 chunks
# 335.wav - file_size:114688 - splitted into 1 chunks
# 336.wav - file_size:6460196 - splitted into 21 chunks
# 337.wav - file_size:352800 - splitted into 2 chunks
# 338.wav - file_size:308700 - splitted into 1 chunks
# 339.wav - file_size:705600 - splitted into 3 chunks
# 34.wav - file_size:1654564 - splitted into 6 chunks
# 340.wav - file_size:221184 - splitted into 1 chunks
# 341.wav - file_size:441000 - splitted into 2 chunks
# 342.wav - file_size:3621099 - splitted into 12 chunks
# 343.wav - file_size:7921344 - splitted into 26 chunks
# 344.wav - file_size:1020672 - splitted into 4 chunks
# 345.wav - file_size:441000 - splitted into 2 chunks
# 346.wav - file_size:617400 - splitted into 2 chunks
# 347.wav - file_size:1288659 - splitted into 5 chunks
# 348.wav - file_size:220500 - splitted into 1 chunks
# 349.wav - file_size:515970 - splitted into 2 chunks
# 35.wav - file_size:5512500 - splitted into 18 chunks
# 350.wav - file_size:529200 - splitted into 2 chunks
# 351.wav - file_size:454230 - splitted into 2 chunks
# 352.wav - file_size:659295 - splitted into 2 chunks
# 353.wav - file_size:4851000 - splitted into 16 chunks
# 354.wav - file_size:441000 - splitted into 2 chunks
# 355.wav - file_size:14157367 - splitted into 46 chunks
# 356.wav - file_size:1940400 - splitted into 7 chunks
# 357.wav - file_size:132300 - splitted into 1 chunks
# 358.wav - file_size:132300 - splitted into 1 chunks
# 359.wav - file_size:3368714 - splitted into 11 chunks
# 36.wav - file_size:88200 - splitted into 1 chunks
# 360.wav - file_size:1146600 - splitted into 4 chunks
# 361.wav - file_size:167580 - splitted into 1 chunks
# 362.wav - file_size:198450 - splitted into 1 chunks
# 363.wav - file_size:2163914 - splitted into 7 chunks
# 364.wav - file_size:264600 - splitted into 1 chunks
# 365.wav - file_size:1411200 - splitted into 5 chunks
# 366.wav - file_size:88200 - splitted into 1 chunks
# 367.wav - file_size:163170 - splitted into 1 chunks
# 368.wav - file_size:242550 - splitted into 1 chunks
# 369.wav - file_size:749700 - splitted into 3 chunks
# 37.wav - file_size:132300 - splitted into 1 chunks
# 370.wav - file_size:617400 - splitted into 2 chunks
# 371.wav - file_size:441000 - splitted into 2 chunks
# 372.wav - file_size:701190 - splitted into 3 chunks
# 373.wav - file_size:793800 - splitted into 3 chunks
# 374.wav - file_size:529200 - splitted into 2 chunks
# 375.wav - file_size:405385 - splitted into 2 chunks
# 376.wav - file_size:273343 - splitted into 1 chunks
# 377.wav - file_size:882000 - splitted into 3 chunks
# 378.wav - file_size:132300 - splitted into 1 chunks
# 379.wav - file_size:132300 - splitted into 1 chunks
# 38.wav - file_size:220500 - splitted into 1 chunks
# 380.wav - file_size:205303 - splitted into 1 chunks
# 381.wav - file_size:573300 - splitted into 2 chunks
# 382.wav - file_size:132300 - splitted into 1 chunks
# 383.wav - file_size:3572100 - splitted into 12 chunks
# 384.wav - file_size:471870 - splitted into 2 chunks
# 385.wav - file_size:198450 - splitted into 1 chunks
# 386.wav - file_size:768734 - splitted into 3 chunks
# 387.wav - file_size:2646000 - splitted into 9 chunks
# 388.wav - file_size:116859 - splitted into 1 chunks
# 389.wav - file_size:749700 - splitted into 3 chunks
# 39.wav - file_size:2778300 - splitted into 9 chunks
# 390.wav - file_size:1014300 - splitted into 4 chunks
# 391.wav - file_size:793800 - splitted into 3 chunks
# 392.wav - file_size:10014570 - splitted into 33 chunks
# 393.wav - file_size:741888 - splitted into 3 chunks
# 394.wav - file_size:793800 - splitted into 3 chunks
# 395.wav - file_size:224910 - splitted into 1 chunks
# 396.wav - file_size:485100 - splitted into 2 chunks
# 397.wav - file_size:207270 - splitted into 1 chunks
# 398.wav - file_size:352800 - splitted into 2 chunks
# 399.wav - file_size:1984500 - splitted into 7 chunks
# 4.wav - file_size:319333 - splitted into 1 chunks
# 40.wav - file_size:5429810 - splitted into 18 chunks
# 400.wav - file_size:304233 - splitted into 1 chunks
# 401.wav - file_size:44100 - splitted into 1 chunks
# 402.wav - file_size:2116800 - splitted into 7 chunks
# 403.wav - file_size:308700 - splitted into 1 chunks
# 404.wav - file_size:617400 - splitted into 2 chunks
# 405.wav - file_size:1058400 - splitted into 4 chunks
# 406.wav - file_size:269010 - splitted into 1 chunks
# 407.wav - file_size:7227865 - splitted into 24 chunks
# 408.wav - file_size:3487582 - splitted into 12 chunks
# 409.wav - file_size:4189500 - splitted into 14 chunks
# 41.wav - file_size:3172542 - splitted into 11 chunks
# 410.wav - file_size:220500 - splitted into 1 chunks
# 411.wav - file_size:185220 - splitted into 1 chunks
# 412.wav - file_size:352800 - splitted into 2 chunks
# 413.wav - file_size:352800 - splitted into 2 chunks
# 414.wav - file_size:88200 - splitted into 1 chunks
# 415.wav - file_size:220500 - splitted into 1 chunks
# 416.wav - file_size:198450 - splitted into 1 chunks
# 417.wav - file_size:617400 - splitted into 2 chunks
# 418.wav - file_size:1068639 - splitted into 4 chunks
# 419.wav - file_size:1499400 - splitted into 5 chunks
# 42.wav - file_size:220500 - splitted into 1 chunks
# 420.wav - file_size:5617260 - splitted into 19 chunks
# 421.wav - file_size:661500 - splitted into 3 chunks
# 422.wav - file_size:132300 - splitted into 1 chunks
# 423.wav - file_size:817152 - splitted into 3 chunks
# 424.wav - file_size:352800 - splitted into 2 chunks
# 425.wav - file_size:1037817 - splitted into 4 chunks
# 426.wav - file_size:793800 - splitted into 3 chunks
# 427.wav - file_size:396900 - splitted into 2 chunks
# 428.wav - file_size:617400 - splitted into 2 chunks
# 429.wav - file_size:329149 - splitted into 1 chunks
# 43.wav - file_size:1117333 - splitted into 4 chunks
# 430.wav - file_size:132300 - splitted into 1 chunks
# 431.wav - file_size:220500 - splitted into 1 chunks
# 432.wav - file_size:705600 - splitted into 3 chunks
# 433.wav - file_size:220500 - splitted into 1 chunks
# 434.wav - file_size:409333 - splitted into 2 chunks
# 435.wav - file_size:243712 - splitted into 1 chunks
# 436.wav - file_size:1014300 - splitted into 4 chunks
# 437.wav - file_size:2469600 - splitted into 8 chunks
# 438.wav - file_size:380863 - splitted into 2 chunks
# 439.wav - file_size:340480 - splitted into 1 chunks
# 44.wav - file_size:2381400 - splitted into 8 chunks
# 440.wav - file_size:529200 - splitted into 2 chunks
# 441.wav - file_size:882000 - splitted into 3 chunks
# 442.wav - file_size:88200 - splitted into 1 chunks
# 443.wav - file_size:1102500 - splitted into 4 chunks
# 444.wav - file_size:79380 - splitted into 1 chunks
# 445.wav - file_size:926100 - splitted into 3 chunks
# 446.wav - file_size:2072700 - splitted into 7 chunks
# 447.wav - file_size:500580 - splitted into 2 chunks
# 448.wav - file_size:441000 - splitted into 2 chunks
# 449.wav - file_size:617400 - splitted into 2 chunks
# 45.wav - file_size:661500 - splitted into 3 chunks
# 450.wav - file_size:441000 - splitted into 2 chunks
# 451.wav - file_size:441000 - splitted into 2 chunks
# 452.wav - file_size:1194819 - splitted into 4 chunks
# 453.wav - file_size:705600 - splitted into 3 chunks
# 454.wav - file_size:132300 - splitted into 1 chunks
# 455.wav - file_size:2940789 - splitted into 10 chunks
# 456.wav - file_size:352800 - splitted into 2 chunks
# 457.wav - file_size:4863861 - splitted into 16 chunks
# 458.wav - file_size:926100 - splitted into 3 chunks
# 459.wav - file_size:132300 - splitted into 1 chunks
# 46.wav - file_size:242550 - splitted into 1 chunks
# 460.wav - file_size:396900 - splitted into 2 chunks
# 461.wav - file_size:5688900 - splitted into 19 chunks
# 462.wav - file_size:242550 - splitted into 1 chunks
# 463.wav - file_size:485100 - splitted into 2 chunks
# 464.wav - file_size:220500 - splitted into 1 chunks
# 465.wav - file_size:2700874 - splitted into 9 chunks
# 466.wav - file_size:308700 - splitted into 1 chunks
# 467.wav - file_size:132300 - splitted into 1 chunks
# 468.wav - file_size:1278900 - splitted into 5 chunks
# 469.wav - file_size:176400 - splitted into 1 chunks
# 47.wav - file_size:3998412 - splitted into 13 chunks
# 470.wav - file_size:2056824 - splitted into 7 chunks
# 471.wav - file_size:441000 - splitted into 2 chunks
# 472.wav - file_size:396900 - splitted into 2 chunks
# 473.wav - file_size:2225846 - splitted into 8 chunks
# 474.wav - file_size:7278804 - splitted into 24 chunks
# 475.wav - file_size:802296 - splitted into 3 chunks
# 476.wav - file_size:5071500 - splitted into 17 chunks
# 477.wav - file_size:493920 - splitted into 2 chunks
# 478.wav - file_size:1896300 - splitted into 7 chunks
# 479.wav - file_size:1102500 - splitted into 4 chunks
# 48.wav - file_size:88200 - splitted into 1 chunks
# 480.wav - file_size:485100 - splitted into 2 chunks
# 481.wav - file_size:101430 - splitted into 1 chunks
# 482.wav - file_size:308700 - splitted into 1 chunks
# 483.wav - file_size:132300 - splitted into 1 chunks
# 484.wav - file_size:2569934 - splitted into 9 chunks
# 485.wav - file_size:2492480 - splitted into 8 chunks
# 486.wav - file_size:132300 - splitted into 1 chunks
# 487.wav - file_size:176400 - splitted into 1 chunks
# 488.wav - file_size:132300 - splitted into 1 chunks
# 489.wav - file_size:970200 - splitted into 4 chunks
# 49.wav - file_size:352800 - splitted into 2 chunks
# 490.wav - file_size:240696 - splitted into 1 chunks
# 491.wav - file_size:617400 - splitted into 2 chunks
# 492.wav - file_size:176400 - splitted into 1 chunks
# 493.wav - file_size:374850 - splitted into 2 chunks
# 494.wav - file_size:89600 - splitted into 1 chunks
# 495.wav - file_size:330640 - splitted into 1 chunks
# 496.wav - file_size:157696 - splitted into 1 chunks
# 497.wav - file_size:220500 - splitted into 1 chunks
# 498.wav - file_size:176400 - splitted into 1 chunks
# 499.wav - file_size:2265120 - splitted into 8 chunks
# 5.wav - file_size:272118 - splitted into 1 chunks
# 50.wav - file_size:6740934 - splitted into 22 chunks
# 500.wav - file_size:638954 - splitted into 2 chunks
# 501.wav - file_size:441000 - splitted into 2 chunks
# 502.wav - file_size:88200 - splitted into 1 chunks
# 503.wav - file_size:837900 - splitted into 3 chunks
# 504.wav - file_size:1058400 - splitted into 4 chunks
# 505.wav - file_size:2352321 - splitted into 8 chunks
# 506.wav - file_size:401408 - splitted into 2 chunks
# 507.wav - file_size:88200 - splitted into 1 chunks
# 508.wav - file_size:1102500 - splitted into 4 chunks
# 509.wav - file_size:390656 - splitted into 2 chunks
# 51.wav - file_size:10080972 - splitted into 33 chunks
# 510.wav - file_size:538880 - splitted into 2 chunks
# 511.wav - file_size:2337300 - splitted into 8 chunks
# 512.wav - file_size:2931993 - splitted into 10 chunks
# 513.wav - file_size:793800 - splitted into 3 chunks
# 514.wav - file_size:352800 - splitted into 2 chunks
# 515.wav - file_size:176400 - splitted into 1 chunks
# 516.wav - file_size:705600 - splitted into 3 chunks
# 517.wav - file_size:88200 - splitted into 1 chunks
# 518.wav - file_size:1026765 - splitted into 4 chunks
# 519.wav - file_size:2293200 - splitted into 8 chunks
# 52.wav - file_size:176400 - splitted into 1 chunks
# 520.wav - file_size:308700 - splitted into 1 chunks
# 521.wav - file_size:2184264 - splitted into 7 chunks
# 522.wav - file_size:176400 - splitted into 1 chunks
# 523.wav - file_size:8209080 - splitted into 27 chunks
# 524.wav - file_size:308700 - splitted into 1 chunks
# 525.wav - file_size:1058400 - splitted into 4 chunks
# 526.wav - file_size:107520 - splitted into 1 chunks
# 527.wav - file_size:308700 - splitted into 1 chunks
# 528.wav - file_size:3131100 - splitted into 11 chunks
# 529.wav - file_size:2490356 - splitted into 8 chunks
# 53.wav - file_size:1455300 - splitted into 5 chunks
# 530.wav - file_size:194435 - splitted into 1 chunks
# 531.wav - file_size:2425054 - splitted into 8 chunks
# 532.wav - file_size:352800 - splitted into 2 chunks
# 533.wav - file_size:290304 - splitted into 1 chunks
# 534.wav - file_size:485100 - splitted into 2 chunks
# 535.wav - file_size:1090560 - splitted into 4 chunks
# 536.wav - file_size:1014300 - splitted into 4 chunks
# 537.wav - file_size:704250 - splitted into 3 chunks
# 538.wav - file_size:333056 - splitted into 1 chunks
# 539.wav - file_size:1984500 - splitted into 7 chunks
# 54.wav - file_size:1922760 - splitted into 7 chunks
# 540.wav - file_size:410935 - splitted into 2 chunks
# 541.wav - file_size:644092 - splitted into 2 chunks
# 542.wav - file_size:705600 - splitted into 3 chunks
# 543.wav - file_size:220500 - splitted into 1 chunks
# 544.wav - file_size:1047816 - splitted into 4 chunks
# 545.wav - file_size:970200 - splitted into 4 chunks
# 546.wav - file_size:88200 - splitted into 1 chunks
# 547.wav - file_size:326340 - splitted into 1 chunks
# 548.wav - file_size:573300 - splitted into 2 chunks
# 549.wav - file_size:573300 - splitted into 2 chunks
# 55.wav - file_size:4410000 - splitted into 15 chunks
# 550.wav - file_size:176400 - splitted into 1 chunks
# 551.wav - file_size:136816 - splitted into 1 chunks
# 552.wav - file_size:441000 - splitted into 2 chunks
# 553.wav - file_size:1940400 - splitted into 7 chunks
# 554.wav - file_size:970200 - splitted into 4 chunks
# 555.wav - file_size:485100 - splitted into 2 chunks
# 56.wav - file_size:132300 - splitted into 1 chunks
# 57.wav - file_size:441000 - splitted into 2 chunks
# 58.wav - file_size:8862876 - splitted into 29 chunks
# 59.wav - file_size:264600 - splitted into 1 chunks
# 6.wav - file_size:3636024 - splitted into 12 chunks
# 60.wav - file_size:88200 - splitted into 1 chunks
# 61.wav - file_size:529200 - splitted into 2 chunks
# 62.wav - file_size:1188387 - splitted into 4 chunks
# 63.wav - file_size:352800 - splitted into 2 chunks
# 64.wav - file_size:970200 - splitted into 4 chunks
# 65.wav - file_size:242550 - splitted into 1 chunks
# 66.wav - file_size:507757 - splitted into 2 chunks
# 67.wav - file_size:525768 - splitted into 2 chunks
# 68.wav - file_size:1096524 - splitted into 4 chunks
# 69.wav - file_size:176400 - splitted into 1 chunks
# 7.wav - file_size:1499400 - splitted into 5 chunks
# 70.wav - file_size:64512 - splitted into 1 chunks
# 71.wav - file_size:88200 - splitted into 1 chunks
# 72.wav - file_size:617400 - splitted into 2 chunks
# 73.wav - file_size:1118208 - splitted into 4 chunks
# 74.wav - file_size:352800 - splitted into 2 chunks
# 75.wav - file_size:1087680 - splitted into 4 chunks
# 76.wav - file_size:1146600 - splitted into 4 chunks
# 77.wav - file_size:4101300 - splitted into 14 chunks
# 78.wav - file_size:352800 - splitted into 2 chunks
# 79.wav - file_size:10895634 - splitted into 36 chunks
# 8.wav - file_size:529200 - splitted into 2 chunks
# 80.wav - file_size:6174000 - splitted into 20 chunks
# 81.wav - file_size:264600 - splitted into 1 chunks
# 82.wav - file_size:529200 - splitted into 2 chunks
# 83.wav - file_size:176400 - splitted into 1 chunks
# 84.wav - file_size:582600 - splitted into 2 chunks
# 85.wav - file_size:1058400 - splitted into 4 chunks
# 86.wav - file_size:661500 - splitted into 3 chunks
# 87.wav - file_size:308700 - splitted into 1 chunks
# 88.wav - file_size:396900 - splitted into 2 chunks
# 89.wav - file_size:1791279 - splitted into 6 chunks
# 9.wav - file_size:3131100 - splitted into 11 chunks
# 90.wav - file_size:264600 - splitted into 1 chunks
# 91.wav - file_size:88200 - splitted into 1 chunks
# 92.wav - file_size:5071500 - splitted into 17 chunks
# 93.wav - file_size:88200 - splitted into 1 chunks
# 94.wav - file_size:127890 - splitted into 1 chunks
# 95.wav - file_size:3536252 - splitted into 12 chunks
# 96.wav - file_size:176400 - splitted into 1 chunks
# 97.wav - file_size:749700 - splitted into 3 chunks
# 98.wav - file_size:264600 - splitted into 1 chunks
# 99.wav - file_size:2381400 - splitted into 8 chunks
# finished chunking, total number of chunks: 2313
# chunked_one_file_dataset: Dataset({
#     features: ['audio', 'file_name'],
#     num_rows: 2313
# })
#
# preprocessing by preprocess_audio_arrays ...
# Map:   0%|          | 0/2313 [00:00<?, ? examples/s]
# calculating predictions by make_chunked_predictions ...
# Map:   0%|          | 0/2313 [00:00<?, ? examples/s]
# predictions:      file_name predicted_class_id
# 0        0.wav                 14  \
# 1        0.wav                 14
# 2        1.wav                 60
# 3       10.wav                 26
# 4       10.wav                 26
# ...        ...                ...
# 2308    99.wav                 39
# 2309    99.wav                 39
# 2310    99.wav                 39
# 2311    99.wav                 39
# 2312    99.wav                 39
#
#                                                  logits
# 0     [-0.06360662, -0.548346, 0.39514756, -0.640027...
# 1     [-0.06094554, -0.5902772, 0.40035322, -0.04751...
# 2     [-1.1129682, -1.5018668, 0.13556546, -0.916900...
# 3     [-0.52893174, 1.666247, -0.8008976, 0.18271926...
# 4     [0.1385512, -1.4241198, -1.9842126, -0.7965207...
# ...                                                 ...
# 2308  [-0.30983245, -0.98355216, 0.23288876, 0.00535...
# 2309  [-0.47169477, -0.8123874, 0.19997203, 0.090179...
# 2310  [-0.43138832, -0.9141567, 0.4489847, -0.167902...
# 2311  [-0.32566267, -0.81515884, 0.42842713, -0.0725...
# 2312  [-0.43709505, -0.9040282, 0.42095152, -0.00592...
#
# [2313 rows x 3 columns]
#
#
# RESULTS SAVED in:
# /root/data/experiments/models/sm-training-custom-2023-07-16-14-12-31-154/checkpoint-13200/predictions_test_7_secs_44100.csv
# /root/data/experiments/exp_2023-07-13_chunk_fixed_predictions/predictions_sm-training-custom-2023-07-16-14-12-31-154_checkpoint-13200_test_7_secs_44100.csv
